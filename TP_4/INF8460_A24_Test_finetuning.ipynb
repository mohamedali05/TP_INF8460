# %% [markdown]
# ## <center> École Polytechnique de Montréal <br> Département Génie Informatique et Génie Logiciel <br>  INF8460 – Traitement automatique de la langue naturelle <br> </center>
# ## <center> TP4 - Les LLMs et la génération augmentée de récupération (RAG) pour les questions-réponses<br> Automne 2024 </center>

# %% [markdown]
# ## Identification de l'équipe:
#
# ### Groupe de laboratoire:
#
# ### Equipe numéro :
#
# ### Membres:
#
# - membre 1 (% de contribution, nature de la contribution)
# - membre 2 (% de contribution, nature de la contribution)
# - membre 3 (% de contribution, nature de la contribution)
#
# * nature de la contribution: Décrivez brièvement ce qui a été fait par chaque membre de l’équipe. Tous les membres sont censés contribuer au développement. Bien que chaque membre puisse effectuer différentes tâches, vous devez vous efforcer d’obtenir une répartition égale du travail. Soyez précis ! N'indiquez pas seulement : travail réparti équitablement

# %% [markdown]
# ## 1. Introduction
#
# ### 1.1. Description du TP4
#
# Dans ce TP, vous allez travailler sur un système de **génération augmentée de récupération**, ou **RAG** (pour Retrieval Augmented Generation en anglais) qui combine des modèles de langue génératifs et de recherche d'information.
#
# Étant donnée une question, il faudra retrouver les passages les plus pertinents  avec un modèle de recherche. Ensuite, il faudra générer une réponse à la question en utilisant ces passages de texte. Vous aurez finalement à trouver des manières d'améliorer les performances de votre modèle RAG.
#
# L'ensemble est noté sur 100 points.
#
# ### Description des données
#
# Les passages donnés sont des textes en anglais de quelques phrases sur divers sujets. Par exemple, les mathématiques, la physique, la chimie, la biologie l'informatique, la musique et la psychologie. En général, les textes abordent des sujets très spécifiques reliés à un domaine. Par exemple, il pourrait y avoir 1000 textes parlant d'informatique et 100 qui abordent, à leur manière, la notion de mémoire. Parmi ces 100 passages, 5 pourraient aborder la mémoire dans un processeur spécifique.
#
# En ce qui concerne les questions, elles sont basées sur les sujets de certains textes précis et on peut y répondre à l'aide d'au moins un des textes. Dans certains cas, plusieurs textes sont nécessaires pour répondre à la question. Par exemple, plusieurs textes pourraient aborder le processeur Intel i7-13700k, mais la question pourrait nécessiter l'information de tous ces textes pour trouver la réponse.
# Les questions ont été créées pour faire en sorte que les réponses soient assez courtes. Il peut s'agir d'un simple nombre ou de quelques mots (< 30 mots).
#
#
# Vous trouverez ~ 13 000 passages dans le corpus pour ~ 1 700 paires de questions / réponses dans le jeu d'entraînement et ~ 500 dans le jeu de validation. Vous devez prédire 500 réponses aux questions du jeu de test.
#
# ### Exemple
#
# Par exemple, pour la question
#
# > What type of bonds are used to form branches in glycogen?
#
# Avec l'approche RAG, plutôt que de générer la réponse directement, on va d'abord chercher dans un corpus de passages. Dans cet exemple, un des passages pertinents est :
#
# > **Glycogen Structure and Function** : Glycogen is a molecular polymer of glucose used for energy storage. It is composed of linear chains of glucose molecules linked by α-1,4-glycosidic bonds, with branches formed off the chain via α-1,6-glycosidic bonds. The branches provide additional ""free ends"" for linear chains, allowing for faster glucose release.
#
# Puis on génère une réponse conditionnée par les passages pertinents :
#
# > α-1,6-glycosidic bonds
#
# ### Motivation
#
# Le RAG est une approche très populaire en ce moment. Elle permet notamment d'avoir des sources qui supportent les réponses générées, ce qui peut être utile pour la vérification de faits ou pour contrôler les hallucinations. De plus, elle permet d'intégrer des connaissances externes et récentes dans les modèles de génération sans avoir à les ré-entraîner.
#
# ### Objectif du TP
#
# Dans ce TP, vous implémenterez plusieurs systèmes de question-réponse. D'abord, vous testerez une approche de prompting qui n'utilise aucun passage pour aider le modèle de génération. Puis vous implémenterez un système figé qui utilise un modèle de plongements figé pour retrouver les $k$ passages les plus pertinents. Ces passages seront ensuite donnés à un modèle de génération figé aussi.
#
# Enfin, vous implémenterez votre propre méthode dans l'objectif d'atteindre les meilleures performances dans la compétition Kaggle.
#
# ### Jeux de données
#
# Vous avez 4 fichiers à votre disposition :
# - 'rag_texts.csv' : le corpus de passages extraits de Wikipédia.
#   - **id** : l'identifiant unique du passage.
#   - **text** : le texte du passage.
# - 'rag_questions_train.csv', 'rag_questions_val.csv' et 'rag_questions_test.csv' : les questions d'entraînement, de validation et de test.
#   - **id** : l'identifiant unique de la question.
#   - **question** : La question.
#   - **text_id** (sauf pour le fichier de test) : la liste des identifiants des passages pertinents du corpus 'rag_texts.csv' pour la question.
#   - **answer** (sauf pour le fichier de test) : la réponse à la question.
#
# ### Contraintes
#
# - **Modèle génératif** : pour des raisons d'équité, le seul modèle de génération que vous pouvez utiliser est [microsoft/Phi-3-mini-128k-instruct](https://huggingface.co/microsoft/Phi-3-mini-128k-instruct), disponible sur Hugging Face. Cette contrainte permet de mieux comparer les différentes approches et d'éviter que la performance soit uniquement due à un modèle de génération plus performant.
# - Données externes : vous ne pouvez pas utiliser de données externes pour entraîner vos modèles, seulement les données fournies.
# - Modèles de plongements à utiliser: [BAAI/bge-small-en-v1.5](https://huggingface.co/BAAI/bge-small-en-v1.5)

# %% [markdown]
# ### 1.2. Librairies permises
#
# Vous pouvez utiliser les librairies suivantes
# - Numpy
# - Pandas
# - HuggingFace
# - nltk
# - SpaCy
# - PyTorch
# - faiss
# - Langchain
# - re
#
#
# - Pour toute autre librairie, demandez à votre chargé de laboratoire

# %% [markdown]
# ### 1.3. Infrastructure
#
# - Vous avez accès aux GPU du local L-4818. Dans ce cas, vous devez utiliser le dossier temp (voir le tutoriel VirtualEnv.pdf)
# - Vous pouvez aussi utiliser l’environnement Google Colab :  https://colab.research.google.com/

# %% [markdown]
# ### 1.4. Remise
#
# ### Échéance
#
# Fin de la session. La date précise sera indiquée dans les boites de remise sur Moodle.

# %% [markdown]
# ### Livrables
#
# Vous devez remettre votre notebook sur Moodle et Gradescope en ipynb et pdf. Pour Gradescope vous devez associer les numéros de questions avec vos réponses dans le pdf grâce à l'outil que fournit Gradescope.
#
#
# ### Critères
# 1. Implantation correcte et efficace
# 2. Richesse de la solution proposée
# 3. Qualité du code (noms significatifs, structure, performance, gestion d’exception, etc.)
# 4. Commentaires clairs et informatifs
# 5. Aspect novateur
# 6. État de l'art synthétisé
# 7. Performance attendue des modèles
# 8. Réponses correctes/sensées aux questions de réflexion ou d'analyse
#
# ### CODE D’HONNEUR
# - __Règle 1__:  Le plagiat de code est bien évidemment interdit. Toute utilisation de code doit être référencée adéquatement. L’utilisation de code ne peut concerner que les architectures de base (par exemple le Transformer). Vous __ne pouvez pas__ soumettre un code écrit par quelqu’un d’autre.
# - __Règle 2__: Vous êtes libres de discuter des idées et des détails de mise en œuvre avec d'autres équipes. Cependant, vous ne pouvez en aucun cas consulter le code d'une autre équipe INF8460, ou incorporer leur code dans votre TP.
# - __Règle 3__:  Vous ne pouvez pas partager votre code publiquement (par exemple, dans un dépôt GitHub public) tant que le cours n'est pas fini.

# %% [markdown]
# ### 1.5. Kaggle
#
# La compétion Kaggle sera accessible ici: https://www.kaggle.com/t/c970abbf273b4e13a642fce3bfe219be.
#
# Vous devez recréer des équipes de 3 personnes sur Kaggle avec le même nom d'équipe que sur Moodle ainsi que les mêmes membres.
#
# Le TP4 se fera sous forme d’une compétition Kaggle.  Vous devrez utiliser l’environnement Kaggle pour la soumission et l’évaluation de vos meilleurs modèles.
# Pour tester votre modèle au fur et à mesure, vous aurez le droit à 4 soumissions par jour sur Kaggle. Il y aura deux types de résultats : votre « private leaderboard » et votre « public leaderboard » :
# - Le « public leaderboard » est calculé sur approximativement 30% des données de test, choisies aléatoirement par Kaggle. Ce score est public et est calculé sur la même tranche de données pour tous les participants.
# - Le « private leaderboard » est calculé sur approximativement 70% des données de test et n’est visible qu’à la fin de la compétition. Le résultat final sera basé sur ce leaderboard. Si aucune soumission n’est choisie, la soumission avec le meilleur score sur le « public leaderboard » sera utilisée pour calculer le score sur le « private leaderboard ».
#
# Pour l’évaluation, vous devrez soumettre un fichier de données _tp4_submission.csv_ du même format que le fichier _sample_submission.csv_ (disponible sur le site de la compétition et Moodle).

# %% [markdown]
# ### 1.6. Description des données et métriques d’évaluation
#
# Dans votre fichier de soumission, il doit y avoir une colonne _id_ et une colonne _answer_. La colonne _id_ doit correspondre à l'identifiant unique de la question et la colonne _answer_ doit correspondre à la réponse générée par votre modèle.
#
# Nous utiliserons la métrique **BLEU**, vue en cours, pour évaluer les réponses générées par rapport au jeu de référence (gold standard).

# %%
# Import des librairies

import os
import torch
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from typing import Optional
from transformers import AutoTokenizer, AutoModel, AutoModelForCausalLM, pipeline, BitsAndBytesConfig
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer
from nltk.translate.bleu_score import sentence_bleu
import nltk
import faiss

from sentence_transformers import InputExample
from sentence_transformers import losses
from sentence_transformers import losses
from sentence_transformers import SentenceTransformer
from sentence_transformers import SentenceTransformerTrainer
from torch.utils.data import DataLoader

# %%
# Si vous stockez vos données sur Google Drive

# from google.colab import drive
# drive.mount('/content/drive')

# %%
root_path = './'
data_path = root_path + 'data/'

# %% [markdown]
# ## 2. Analyse exploratoire et modèle de génération simple (15 points)
#
# Pour commencer ce TP, et pour fixer des modèles de base (baselines), vous allez utiliser un modèle de génération simple pour répondre aux questions. Vous utiliserez le modèle de génération **'microsoft/Phi-3-mini-128k-instruct'** disponible sur Hugging Face. Dans cette partie, vous devez simplement générer des réponses aux questions de l'ensemble de validation (_questions_val.csv_) sans utiliser de passages pour aider le modèle.

# %% [markdown]
# ### 2.1. Chargement des données (5 points)

# %% [markdown]
# #### 2.1.1 Taille des données (1 point)
#
# Affichez la taille de tous les jeux de données et quelques questions de l'ensemble d'entraînement

# %%
# TODO

questions_test = pd.read_csv(data_path + 'questions_test.csv')
questions_train = pd.read_csv(data_path + 'questions_train.csv')
questions_val = pd.read_csv(data_path + 'questions_val.csv')
texts = pd.read_csv(data_path + 'texts.csv')

print(f"Taille du jeu d'entrainement : {len(questions_train)} \nTaille du jeu de validation : {len(questions_val)} \nTaille du jeu de test  :{len(questions_test)}\n")

print("Quelques questions de l'ensemble d'entrainement :")
questions_train['question'].head()

# END TODO
# Out:
# Taille du jeu d'entrainement : 1747
# Taille du jeu de validation : 500
# Taille du jeu de test  :500
#
# Quelques questions de l'ensemble d'entrainement :
# 0    What type of insects are vectors for the Haemo...
# 1    What is the basis of the security of the BBS a...
# 2    What is the purpose of the catalase test in ba...
# 3    What type of cells clear small particles in ve...
# 4    What information is needed to decrypt a messag...
# Name: question, dtype: object

# %% [markdown]
# #### 2.1.2 Analyse exploratoire (4 points)
#
# a) Sur l'ensemble d'entraînement, affichez :
# - Le nombre moyen de mots dans une question
# - Le nombre moyen de mots dans une réponse
# - Le nombre moyen de passages nécessaires pour répondre à une question
# - Le nombre minimal de passages nécessaires pour répondre à une question
# - Le nombre maximal de passages nécessaires pour répondre à une question

# %%
# TODO

data_question_word_count = questions_train['question'].apply(lambda x: len(x.split()))
mean_words_q = round(np.mean(data_question_word_count), 2)


data_answer_word_count = questions_train['answer'].apply(lambda x: len(x.split()))
mean_words_r = round(np.mean(data_answer_word_count), 2)

mean_passages = round(np.mean(questions_train['text_ids'].apply(lambda x: len(x.split()))),2)
min_passages = np.min(questions_train['text_ids'].apply(lambda x: len(x.split())))
max_passages = np.max(questions_train['text_ids'].apply(lambda x: len(x.split())))

print(f"Le nombre moyen de mots dans une question : {mean_words_q}\n"
      f"Le nombre moyen de mots dans une réponse : {mean_words_r}\n"
      f"Le nombre moyen de passages nécessaires pour répondre à une question : {mean_passages}\n"
      f"Le nombre minimal de passages nécessaires pour répondre à une question : {min_passages}\n"
      f"Le nombre maximal de passages nécessaires pour répondre à une question : {max_passages}\n")

# END TODO
# Out:
# Le nombre moyen de mots dans une question : 10.37
# Le nombre moyen de mots dans une réponse : 6.08
# Le nombre moyen de passages nécessaires pour répondre à une question : 2.84
# Le nombre minimal de passages nécessaires pour répondre à une question : 2
# Le nombre maximal de passages nécessaires pour répondre à une question : 4

# %% [markdown]
# b) De plus, affichez des histogrammes décrivant la distribution du nombre de mots des questions, des réponses et des textes. Utilisez des bacs (bins) de 50. Commentez vos résultats.

# %%
# TODO

texts_world_count = texts['text'].apply(lambda x: len(x.split()))
bins = 50

plt.figure(figsize=(14, 5))

plt.subplot(1, 3, 1)
plt.hist(data_question_word_count, bins=bins, color='skyblue')
plt.title('Distribution du nombre de mots des questions')
plt.xlabel('Nombre de mots')
plt.ylabel('Fréquence')

plt.subplot(1, 3, 2)
plt.hist(data_answer_word_count, bins=bins, color='lightgreen')
plt.title('Distribution du nombre de mots des réponses')
plt.xlabel('Nombre de mots')
plt.ylabel('Fréquence')

plt.subplot(1, 3, 3)
plt.hist(texts_world_count, bins=bins, color='salmon')
plt.title('Distribution du nombre de mots des textes')
plt.xlabel('Nombre de mots')
plt.ylabel('Fréquence')

plt.tight_layout()
plt.show()

# TODO

# %% [markdown]
# COMMENTAIRE:

# %% [markdown]
# ### 2.2. Chargement du modèle et génération des réponses (5 points)
#
# Nous allons maintenant évaluer la performance d'un modèle de langue à répondre aux questions de l'ensemble de validation. Chargez d'abord le modèle **'microsoft/Phi-3-mini-128k-instruct'** avec la librairie `transformers` de huggingface et générez les réponses du modèle à partir de la question. Générez au maximum 32 nouveaux jetons.

# %%
import torch
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
from transformers import BitsAndBytesConfig

config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
)
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[7], line 4
#       1 import torch
#       2 from transformers import BitsAndBytesConfig
# ----> 4 config = BitsAndBytesConfig(
#       5     load_in_4bit=True,
#       6     bnb_4bit_quant_type="nf4",
#       7     bnb_4bit_use_double_quant=True,
#       8     bnb_4bit_compute_dtype=torch.bfloat16,
#       9 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/quantization_config.py:417, in BitsAndBytesConfig.__init__(self, load_in_8bit, load_in_4bit, llm_int8_threshold, llm_int8_skip_modules, llm_int8_enable_fp32_cpu_offload, llm_int8_has_fp16_weight, bnb_4bit_compute_dtype, bnb_4bit_quant_type, bnb_4bit_use_double_quant, bnb_4bit_quant_storage, **kwargs)
#     414 if kwargs:
#     415     logger.warning(f"Unused kwargs: {list(kwargs.keys())}. These kwargs are not used in {self.__class__}.")
# --> 417 self.post_init()
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/quantization_config.py:475, in BitsAndBytesConfig.post_init(self)
#     472 if not isinstance(self.bnb_4bit_use_double_quant, bool):
#     473     raise TypeError("bnb_4bit_use_double_quant must be a boolean")
# --> 475 if self.load_in_4bit and not version.parse(importlib.metadata.version("bitsandbytes")) >= version.parse(
#     476     "0.39.0"
#     477 ):
#     478     raise ValueError(
#     479         "4 bit quantization requires bitsandbytes>=0.39.0 - please upgrade your bitsandbytes version"
#     480     )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/importlib/metadata/__init__.py:996, in version(distribution_name)
#     989 def version(distribution_name):
#     990     """Get the version string for the named package.
#     991
#     992     :param distribution_name: The name of the distribution package to query.
#     993     :return: The version string for the package as defined in the package's
#     994         "Version" metadata key.
#     995     """
# --> 996     return distribution(distribution_name).version
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/importlib/metadata/__init__.py:969, in distribution(distribution_name)
#     963 def distribution(distribution_name):
#     964     """Get the ``Distribution`` instance for the named package.
#     965
#     966     :param distribution_name: The name of the distribution package as a string.
#     967     :return: A ``Distribution`` instance (or subclass thereof).
#     968     """
# --> 969     return Distribution.from_name(distribution_name)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/importlib/metadata/__init__.py:548, in Distribution.from_name(cls, name)
#     546         return dist
#     547 else:
# --> 548     raise PackageNotFoundError(name)
#
# PackageNotFoundError: No package metadata was found for bitsandbytes

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = 'microsoft/Phi-3-mini-128k-instruct'
gen_tokenizer = AutoTokenizer.from_pretrained(model_name)
gen_model = AutoModelForCausalLM.from_pretrained( 
    "microsoft/Phi-3-mini-128k-instruct",  
    device_map=DEVICE,  
    torch_dtype=torch.bfloat16,  
    trust_remote_code=True,
    #quantization_config=config  
)
# Out:
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def process_batch(batch_questions, tokenizer, model, context, device):
    inputs = [
        tokenizer.apply_chat_template(
            [{'role': 'system', 'content': 'You are a helpful assistant.'},
             {'role': 'user', 'content': context + question}],
            tokenize=False,
            add_generation_prompt=True
        )
        for question in batch_questions
    ]
    inputs = tokenizer(inputs, return_tensors="pt", padding=True).to(device)

    outputs = model.generate(
        input_ids=inputs['input_ids'],
        attention_mask=inputs['attention_mask'],
        max_new_tokens=32
    )
    responses = [
        tokenizer.decode(output[inputs.input_ids.size(1):], skip_special_tokens=True)
        for output in outputs
    ]
    return responses

# %%
# import time

batch_size = 16
questions_val = pd.read_csv(data_path + 'questions_val.csv')
questions = questions_val['question'].tolist()
# context = "Answer using as few words as possible : "
context = "Give a concise answer : "

generated_responses = []
for i in range(0, len(questions), batch_size):
    batch_questions = questions[i:i + batch_size]

    # print(f"[Batch {i}] Started generation...")
    # start_time = time.time()

    batch_response = process_batch(batch_questions, gen_tokenizer, gen_model, context, DEVICE)
    generated_responses.extend(batch_response)

    # end_time = time.time()
    # elapsed_time = end_time - start_time
    
    # print(f"[Batch {i}] Time for generation = {elapsed_time:.2f} seconds")

print(generated_responses)
# Out:
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# You are not running the flash-attention implementation, expect numerical differences.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 16
#      11 batch_questions = questions[i:i + batch_size]
#      13 # print(f"[Batch {i}] Started generation...")
#      14 # start_time = time.time()
# ---> 16 batch_response = process_batch(batch_questions, gen_tokenizer, gen_model, context, DEVICE)
#      17 generated_responses.extend(batch_response)
#      19 # end_time = time.time()
#      20 # elapsed_time = end_time - start_time
#      21
#      22 # print(f"[Batch {i}] Time for generation = {elapsed_time:.2f} seconds")
#
# Cell In[10], line 13, in process_batch(batch_questions, tokenizer, model, context, device)
#       2 inputs = [
#       3     tokenizer.apply_chat_template(
#       4         [{'role': 'system', 'content': 'You are a helpful assistant.'},
#    (...)
#       9     for question in batch_questions
#      10 ]
#      11 inputs = tokenizer(inputs, return_tensors="pt", padding=True).to(device)
# ---> 13 outputs = model.generate(
#      14     input_ids=inputs['input_ids'],
#      15     attention_mask=inputs['attention_mask'],
#      16     max_new_tokens=32
#      17 )
#      18 responses = [
#      19     tokenizer.decode(output[inputs.input_ids.size(1):], skip_special_tokens=True)
#      20     for output in outputs
#      21 ]
#      22 return responses
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/generation/utils.py:2215, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2207     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2208         input_ids=input_ids,
#    2209         expand_size=generation_config.num_return_sequences,
#    2210         is_encoder_decoder=self.config.is_encoder_decoder,
#    2211         **model_kwargs,
#    2212     )
#    2214     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2215     result = self._sample(
#    2216         input_ids,
#    2217         logits_processor=prepared_logits_processor,
#    2218         stopping_criteria=prepared_stopping_criteria,
#    2219         generation_config=generation_config,
#    2220         synced_gpus=synced_gpus,
#    2221         streamer=streamer,
#    2222         **model_kwargs,
#    2223     )
#    2225 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2226     # 11. prepare beam search scorer
#    2227     beam_scorer = BeamSearchScorer(
#    2228         batch_size=batch_size,
#    2229         num_beams=generation_config.num_beams,
#    (...)
#    2234         max_length=generation_config.max_length,
#    2235     )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/generation/utils.py:3206, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3203 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3205 # forward pass to get next token
# -> 3206 outputs = self(**model_inputs, return_dict=True)
#    3208 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3209 model_kwargs = self._update_model_kwargs_for_generation(
#    3210     outputs,
#    3211     model_kwargs,
#    3212     is_encoder_decoder=self.config.is_encoder_decoder,
#    3213 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /home/zeus/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/a90b62ae09941edff87a90ced39ba5807e6b2ade/modeling_phi3.py:1243, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1240 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1242 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1243 outputs = self.model(
#    1244     input_ids=input_ids,
#    1245     attention_mask=attention_mask,
#    1246     position_ids=position_ids,
#    1247     past_key_values=past_key_values,
#    1248     inputs_embeds=inputs_embeds,
#    1249     use_cache=use_cache,
#    1250     output_attentions=output_attentions,
#    1251     output_hidden_states=output_hidden_states,
#    1252     return_dict=return_dict,
#    1253 )
#    1255 hidden_states = outputs[0]
#    1256 logits = self.lm_head(hidden_states)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /home/zeus/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/a90b62ae09941edff87a90ced39ba5807e6b2ade/modeling_phi3.py:1121, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1111     layer_outputs = self._gradient_checkpointing_func(
#    1112         decoder_layer.__call__,
#    1113         hidden_states,
#    (...)
#    1118         use_cache,
#    1119     )
#    1120 else:
# -> 1121     layer_outputs = decoder_layer(
#    1122         hidden_states,
#    1123         attention_mask=attention_mask,
#    1124         position_ids=position_ids,
#    1125         past_key_value=past_key_values,
#    1126         output_attentions=output_attentions,
#    1127         use_cache=use_cache,
#    1128     )
#    1130 hidden_states = layer_outputs[0]
#    1132 if use_cache:
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /home/zeus/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/a90b62ae09941edff87a90ced39ba5807e6b2ade/modeling_phi3.py:842, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     839 hidden_states = self.input_layernorm(hidden_states)
#     841 # Self Attention
# --> 842 attn_outputs, self_attn_weights, present_key_value = self.self_attn(
#     843     hidden_states=hidden_states,
#     844     attention_mask=attention_mask,
#     845     position_ids=position_ids,
#     846     past_key_value=past_key_value,
#     847     output_attentions=output_attentions,
#     848     use_cache=use_cache,
#     849 )
#     851 hidden_states = residual + self.resid_attn_dropout(attn_outputs)
#     853 residual = hidden_states
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /home/zeus/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/a90b62ae09941edff87a90ced39ba5807e6b2ade/modeling_phi3.py:334, in Phi3Attention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     328         raise ValueError(
#     329             f"The cache structure has changed since version v4.36. If you are using {self.__class__.__name__} "
#     330             "for auto-regressive decoding with k/v caching, please make sure to initialize the attention class "
#     331             "with a layer index."
#     332         )
#     333     kv_seq_len += past_key_value.get_usable_length(kv_seq_len, self.layer_idx)
# --> 334 cos, sin = self.rotary_emb(value_states, position_ids, seq_len=kv_seq_len)
#     336 query_states, key_states = apply_rotary_pos_emb(query_states, key_states, cos, sin, position_ids)
#     338 if past_key_value is not None:
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /home/zeus/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/a90b62ae09941edff87a90ced39ba5807e6b2ade/modeling_phi3.py:153, in Phi3LongRoPEScaledRotaryEmbedding.forward(self, x, position_ids, seq_len)
#     150 @torch.no_grad()
#     151 def forward(self, x, position_ids, seq_len=None):
#     152     seq_len = torch.max(position_ids) + 1
# --> 153     if seq_len > self.original_max_position_embeddings:
#     154         ext_factors = torch.tensor(self.long_factor, dtype=torch.float32, device=x.device)
#     155     else:
#
# KeyboardInterrupt:

# %%
df_true = questions_val[['id', 'answer']].copy()
df_pred = questions_val[['id']].copy()
df_pred['answer'] = generated_responses

# %% [markdown]
# ### 2.3. Évaluation des réponses (3 points)
#
# Complétez la fonction `evaluate_bleu` et utilisez la métrique BLEU pour évaluer les réponses générées par rapport aux réponses attendues sur le jeu de validation. Évaluez votre modèle avec les métriques BLEU-1 et BLEU-2. BLEU-1 ne considère que les unigrammes pour évaluer la réponse et BLEU-2 considère les bigrammes aussi. Pour séparer une séquence en mots, vous pouvez simplement utiliser la fonction `split()`.

# %%
import warnings
from nltk.translate.bleu_score import sentence_bleu

def evaluate_bleu(df_true: pd.DataFrame, df_pred: pd.DataFrame, bleu_type: int):
    """
    Évalue les réponses générées en utilisant la métrique BLEU.

    Paramètres:
    df_true (pd.DataFrame): DataFrame contenant les vraies réponses avec des colonnes 'id' et 'answer'.
    df_pred (pd.DataFrame): DataFrame contenant les réponses prédites avec des colonnes 'id' et 'answer'.
    bleu_type (int): Nombre (soit 1 ou 2) correspondant aux n-grammes considérés pour la métrique (bleu_type = 1 : BLEU-1, bleu_type = 2 : BLEU-2)

    Retourne:
    float: Score BLEU moyen sur toutes les entrées.
    """
    # TODO

    df_merged = pd.merge(df_true[['id', 'answer']], df_pred[['id', 'answer']], on='id', suffixes=('_true', '_pred'))

    weights = (1.0, 0.0, 0.0, 0.0) if bleu_type == 1 else (0.5, 0.5, 0.0, 0.0)
    
    bleu_scores = []

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        for _, row in df_merged.iterrows():
            reference = row['answer_true'].split()
            candidate = row['answer_pred'].split() 

            bleu_score = sentence_bleu([reference], candidate, weights=weights)
            bleu_scores.append(bleu_score)
        
    mean_bleu = sum(bleu_scores) / len(bleu_scores)
    return mean_bleu

    # END TODO

# %%
# TODO
print(f"Le score BLEU-1 est {evaluate_bleu(df_true, df_pred, 1):.3f}.")
print(f"Le score BLEU-2 est {evaluate_bleu(df_true, df_pred, 2):.3f}.")
# TODO
# Out:
# Le score BLEU-1 est 0.180.
# Le score BLEU-2 est 0.078.

# %% [markdown]
# ### 2.4. Commentaire (2 points)
#
# Reportez, puis commentez la performance obtenue ici.

# %% [markdown]
# Performance obtenue:

# %% [markdown]
# ## 3. Approche RAG figé (45 points)
#
# Dans cette partie, vous allez implémenter une approche simple de RAG figé. On dit ici que le modèle est figé car on ne ré-entraîne aucun modèle. Vous implémenterez deux variantes : avec ou sans l'utilisation d'un algorithme d'indexation.
#
# Dans la méthode d'implémentation du RAG figé, vous allez d'abord retrouver les passages pertinents pour chaque question avec un modèle de plongements de type Transformers, puis générer une réponse conditionnée par ces passages.
#
# Dans cette partie, on utilisera
# - le modèle de plongements (embedding-model) **[BAAI/bge-small-en-v1.5](https://huggingface.co/BAAI/bge-small-en-v1.5)** pour obtenir les vecteur de plongements des questions et des passages
# - le modèle de génération (generative-model) **[microsoft/Phi-3-mini-128k-instruct](https://huggingface.co/microsoft/Phi-3-mini-128k-instruct)** pour générer les réponses

# %% [markdown]
# ### 3.1 RAG figé sans indexation (23 points)

# %% [markdown]
# #### 3.1.1 Passages pertinents (8 points)
#
# Pour retrouver les passages pertinents, vous devez d'abord encoder les questions et les passages avec le modèle de plongements. Puis, vous devez calculer la similarité cosinus entre les questions et les passages pour retrouver les $k$ passages les plus pertinents pour chaque question.

# %%
BATCH_SIZE = 32

# %%
# TODO
from transformers import AutoTokenizer, AutoModel
model_name = 'BAAI/bge-small-en-v1.5'
emb_tokenizer = AutoTokenizer.from_pretrained(model_name)
emb_model = AutoModel.from_pretrained(model_name)
emb_model.to(DEVICE)
# END TODO
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 384, padding_idx=0)
#     (position_embeddings): Embedding(512, 384)
#     (token_type_embeddings): Embedding(2, 384)
#     (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=384, out_features=384, bias=True)
#             (key): Linear(in_features=384, out_features=384, bias=True)
#             (value): Linear(in_features=384, out_features=384, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=384, out_features=384, bias=True)
#             (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=384, out_features=1536, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=1536, out_features=384, bias=True)
#           (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=384, out_features=384, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def encode_sequences(sequences: list, tokenizer, model, device = DEVICE, batch_size = BATCH_SIZE):
    """
    Encode les textes en utilisant le modèle passé en paramètre pour générer les plongements des textes

    Paramètres:
    sequences    : Liste de séquence à transformer en plongements
    tokenizer   : Segmenteur du modèle de plongements
    model       : Modèle de plongements
    device      : Machine sur laquelle les opérations doivent être effectuées
    batch_size  : Taille des lots lors de la génération des traitements
    """
    # TODO

    model.eval()

    embeddings = []
    
    for i in range(0, len(sequences), batch_size):
        batch = sequences[i:i + batch_size]
    
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt").to(device)
        
        with torch.no_grad():
            output = model(**inputs).last_hidden_state # .last_hidden_state : Dimension (torch.Size([batch_size, sequence_length, hidden_size])) -> chaque token de la séquence à un plongement de taille 384 !
            embedding = output.mean(dim=1)  # Moyenne sur la dimension des tokens (dimension sequence_length) pour avoir la représentation de la séquence
            embeddings.append(embedding)
    
    return torch.cat(embeddings, dim=0)

    # END TODO

# %% [markdown]
# #### 3.1.2 Évaluation des passages retrouvés avec Recall@k et precision@k (7 points)
#
# Maintenant que les passages ont tous été encodés, on peut évaluer si les passages retrouvés sont pertinents. En prenant les $k$ premiers passages, on peut évaluer si on retrouve les bons passages associés aux questions. C'est un des avantages du système RAG : on peut évaluer de façon indépendante la qualité du système qui retrouve les passages pertinents et de celui qui génère les réponses. Cela permet notamment d'évaluer quels sont les points forts et points faibles du système.
#
# Pour cela, vous allez utiliser les métriques **Precision@k** et **Recall@k** définies dans les équations suivantes. Implémentez ces métriques.
#
# $$\text{Precision@k} = \frac{\text{Nombre d'éléments pertinents dans les k premiers}}{k}$$
#
# $$\text{Recall@k} (Rappel@k) = \frac{\text{Nombre d'éléments pertinents dans les k premiers}}{\text{Nombre total d'éléments pertinents}}$$

# %%
def compute_recall_at_k(ground_truth, predictions):
    """
    Calcule la métrique du "Recall@k". On assume que predictions contiennent le bon nombre de passages (=k)

    Paramètres:
    ground_truth : Liste contenant tous les vrais passages associés aux questions (ex : [[1, 2, 3], [4, 5, 6]] si les passages de la question 1 sont [1, 2, 3] et 
    les passages de la question 2 sont [4, 5, 6])
    predictions : Liste contenant tous les passages retrouvés pour chacune des questions formattée de la même manière que `ground_truth`

    Retourne:
    Recall moyen
    """
    # TODO
    total_recall = 0
    for true_texts, predicted_texts in zip(ground_truth, predictions):

        true_set = set(true_texts)  
        predicted_set = set(predicted_texts)

        relevant_and_retrieved = true_set.intersection(predicted_set)
        
        recall = len(relevant_and_retrieved) / len(true_set)
        total_recall += recall
   
    average_recall = total_recall / len(ground_truth) 
    return average_recall

    # END TODO

# %%
def compute_precision_at_k(ground_truth, predictions):
    """
    Calcule la métrique du "Precision@k". On assume que predictions contiennent le bon nombre de passages (=k)

    Paramètres:
    ground_truth : Liste contenant tous les vrais passages associés aux questions (ex : [[1, 2, 3], [4, 5, 6]] si les passages de la question 1 sont [1, 2, 3] et 
    les passages de la question 2 sont [4, 5, 6])
    predictions : Liste contenant tous les passages retrouvés pour chacune des questions formattée de la même manière que `ground_truth`

    Retourne: 
    Précision moyenne
    """

    # TODO

    total_precision = 0
    for true_texts, predicted_texts in zip(ground_truth, predictions):
        true_set = set(true_texts)
        predicted_set = set(predicted_texts)
        relevant_and_retrieved = true_set.intersection(predicted_set)
        
        precision = len(relevant_and_retrieved) / len(predicted_set) 
        total_precision += precision
    
    average_precision = total_precision / len(ground_truth) 
    return average_precision

    # END TODO

# %% [markdown]
# #### 3.1.3 Résultat d'évaluation (5 points)
# Implémentez la fonction _'retrieve_passages'_ qui retourne les indices des $k$ passages les plus similaires pour une question. Utilisez la similarité cosinus pour comparer les passages et les questions. Évaluez ensuite votre modèle récupérant les passages avec les métriques Precision@k et Recall@k sur le jeu de validation. Calculez avec $k={1, 2, 3, 4, 5}$.

# %%
def cosine_similarity(questions_encoded, text_embeddings):
    # Normalisation des embeddings
    questions_normed = questions_encoded / torch.norm(questions_encoded, p=2, dim=1, keepdim=True)
    texts_normed = text_embeddings / torch.norm(text_embeddings, p=2, dim=1, keepdim=True)
    
    # Calcul de la similarité cosinus
    cosine_distance = torch.mm(questions_normed, texts_normed.t())
    return cosine_distance

# %%
import torch
import torch.nn.functional as F

def retrieve_passages(questions: list, passage_embed: torch.Tensor, k: int, embedding_model_tokenizer, embedding_model):
    """
    Retourne les k passages les plus pertinents pour chaque question passée en paramètre

    Paramètres:
    questions       : Les questions pour lesquelles on cherche les passages les plus pertinents
    passage_embed   : Tenseur contenant les plongements de chaque passage (n, dim)
    k               : le nombre de passages à retourner
    tokenizer       : Segmenteur du modèle de plongements
    model           : Modèle de plongements

    Retourne:
    Les indices des k passages les plus pertinents pour la question
    """
    # TODO

    question_embeddings = encode_sequences(questions, embedding_model_tokenizer, embedding_model)
    # print(question_embeddings.unsqueeze(1)) # Dimension (nb_questions, 1, 384)
    # print(passage_embed.unsqueeze(0)) # Dimension (1, nb_passages, 384)
    # similarities = F.cosine_similarity(question_embeddings.unsqueeze(1), passage_embed.unsqueeze(0), dim=-1) # Dimension  (nb_questions, nb_passages)
    similarities = cosine_similarity(question_embeddings, passage_embed)
    top_k_indices = torch.topk(similarities, k=k, dim=-1).indices.tolist() # Indices du topk des passages (dim=-1) pour une question donnée

    return top_k_indices

    # END TODO

# %%
# TODO
passages = texts['text'].tolist()
questions = questions_val['question'].tolist()

passage_embed = encode_sequences(passages, emb_tokenizer, emb_model)
# END TODO

# %% [markdown]
# ## finetuning of the model

# %% [markdown]
# ### Using Sentence_Transformer

# %%
# TODO
from transformers import AutoTokenizer, AutoModel
model_name = 'BAAI/bge-small-en-v1.5'
emb_tokenizer = AutoTokenizer.from_pretrained(model_name)
emb_model = AutoModel.from_pretrained(model_name).to(DEVICE)

# END TODO

# %%
model = SentenceTransformer('BAAI/bge-small-en-v1.5')

# %%
MAX_NEGATIVES = 5

top_passages = retrieve_passages(questions_train['question'].tolist(), passage_embed, 7, emb_tokenizer, emb_model)
top_ground_truth = questions_train['text_ids'].apply(lambda x: [int(num) for num in x.strip('[]').split()]).to_list()

hard_negative_pairs = []

for index , question in questions_train.iterrows() : 
    #print(question)
    ground_truth = top_ground_truth[index]
    retrieved_indices = top_passages[index]
    hard_negatives = [texts[texts['id'] == idx]['text'].iloc[0]for idx in retrieved_indices if idx not in ground_truth]
  
    
    for index_passage in ground_truth : 
        dict = {'catcher' : question['question'] , 
        'positive': texts[texts['id'] == index_passage]['text'].iloc[0] ,'negative' : hard_negatives[0]  }
        hard_negative_pairs.append(dict)

# %%
columnar_data = {
    'anchor': [pair['catcher'] for pair in hard_negative_pairs],
    'positive': [pair['positive'] for pair in hard_negative_pairs],
    'negative': [pair['negative'] for pair in hard_negative_pairs],
}

# Create a Hugging Face Dataset
from datasets import Dataset

hf_dataset = Dataset.from_dict(columnar_data)

# %%
# train_examples = []
# for pair in hard_negative_pairs:
#     # Add positive examples
#     train_examples.append(InputExample(texts=[pair["question"], pair["positive"]], label=1.0))
#     # Add hard negatives
#     for negative in pair["negatives"]:
#         train_examples.append(InputExample(texts=[pair["question"], negative], label=0.0))

# %%
from sentence_transformers import losses
from sentence_transformers import SentenceTransformerTrainingArguments

loss = losses.MultipleNegativesRankingLoss(model)
# 5. (Optional) Specify training arguments
args = SentenceTransformerTrainingArguments(
    # Required parameter:
    #output_="mpnet-base-all-nli-triplet",
    # Optional training parameters:
    num_train_epochs=1,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    warmup_ratio=0.1,
    fp16=True,  # Set to False if GPU can't handle FP16
    bf16=False,  # Set to True if GPU supports BF16
    #batch_sampler=BatchSamplers.NO_DUPLICATES,  # MultipleNegativesRankingLoss benefits from no duplicates
    # Optional tracking/debugging parameters:
    #eval_strategy="steps",
    #eval_steps=100,
    remove_unused_columns=False,
    save_strategy="steps",
    save_steps=100,
    save_total_limit=2,
    logging_steps=100,
    run_name="mpnet-base-all-nli-triplet",
    output_dir = "./model"  # Used in W&B if `wandb` is installed
)

# %%
# from transformers import TrainingArguments, Trainer


# trainer = Trainer(
#     model=model,
#     args=args,
#     train_dataset=hf_dataset,
#     #tokenizer=emb_tokenizer,  # Pass the tokenizer if needed
   
# )

# # 7. Train the model
# trainer.train()

# # 8. Save the model
# emb_model.save('./fine_tuned_with_hard_negatives')
# trainer.fit()

# %%
def encode_sequences(sequences: list, tokenizer, model, device = DEVICE, batch_size = BATCH_SIZE):
    """
    Encode les textes en utilisant le modèle passé en paramètre pour générer les plongements des textes

    Paramètres:
    sequences    : Liste de séquence à transformer en plongements
    tokenizer   : Segmenteur du modèle de plongements
    model       : Modèle de plongements
    device      : Machine sur laquelle les opérations doivent être effectuées
    batch_size  : Taille des lots lors de la génération des traitements
    """
    # TODO

    model.eval()

    embeddings = []
    
    embeddings = model.encode(
        sequences,
        batch_size=batch_size,
        show_progress_bar=True,
        device=device,  # Ensure encoding happens on the specified device
        convert_to_tensor=True  # Convert output to PyTorch tensors
    )
    print(embeddings.shape)
    return embeddings

    # END TODO

# %%
train_examples = [
    InputExample(texts=[row['anchor'], row['positive'], row['negative']])
    for _, row in hf_dataset.to_pandas().iterrows()
]

# Create a DataLoader for the dataset
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)

# Define the loss function
train_loss = losses.MultipleNegativesRankingLoss(model)

# Train the model
model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=10,
    warmup_steps=100,
    output_path='./fine_tuned_with_hard_negatives',
    optimizer_params={'lr': 5e-5}  # Set the learning rate
)

# Save the trained model
model.save('./fine_tuned_with_hard_negatives')

# %%
passage_embed = encode_sequences(passages, emb_tokenizer, model)

# %%
recall = []
precision = []
passage_embed = encode_sequences(passages, emb_tokenizer, model)

for k in range(1,6) : 
    top_passages = retrieve_passages(questions, passage_embed, k, emb_tokenizer, model)
    recall.append(compute_recall_at_k(top_ground_truth, top_passages))
    precision.append(compute_precision_at_k(top_ground_truth, top_passages))

# %%
print(top_passages)

# %%
top_ground_truth

# %%
plt.plot(range(1,6), recall, marker='o', color='b', label='Recall@k')
plt.plot(range(1,6), precision, marker='x', color='r', label='Precision@k')
plt.xlabel('k (Number of passages consider)')
plt.ylabel('Metric value')
plt.title('Recall and Precision at different k values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# the method doesn't work so we try an other approach
# #### Classic finetuning method

# %%
# TODO
from transformers import AutoTokenizer, AutoModel
model_name = 'BAAI/bge-small-en-v1.5'
emb_tokenizer = AutoTokenizer.from_pretrained(model_name)
emb_model = AutoModel.from_pretrained(model_name).to(DEVICE)

# END TODO

# %%
MAX_NEGATIVES = 5


top_ground_truth = questions_train['text_ids'].apply(lambda x: [int(num) for num in x.strip('[]').split()]).to_list()

hard_negative_pairs = []
questions_string = []
positives_string = []
negatives_string = []

for index , question in questions_train.iterrows() : 
    #print(question)
    ground_truth = top_ground_truth[index]
    retrieved_indices = top_passages[index]
    hard_negatives = [texts[texts['id'] == idx]['text'].iloc[0]for idx in retrieved_indices if idx not in ground_truth]
  
    
    for index_passage in ground_truth : 
        questions_string.append(question['question'])
        positives_string.append(texts[texts['id'] == index_passage]['text'].iloc[0])
        negatives_string.append(hard_negatives[0])

# %%
def encode_sequences(sequences: list, tokenizer, model, device = DEVICE, batch_size = BATCH_SIZE):
    """
    Encode les textes en utilisant le modèle passé en paramètre pour générer les plongements des textes

    Paramètres:
    sequences    : Liste de séquence à transformer en plongements
    tokenizer   : Segmenteur du modèle de plongements
    model       : Modèle de plongements
    device      : Machine sur laquelle les opérations doivent être effectuées
    batch_size  : Taille des lots lors de la génération des traitements
    """
    # TODO

    model.eval()

    embeddings = []
    
    for i in range(0, len(sequences), batch_size):
        batch = sequences[i:i + batch_size]
    
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt").to(device)
        output = model(**inputs).last_hidden_state # .last_hidden_state : Dimension (torch.Size([batch_size, sequence_length, hidden_size])) -> chaque token de la séquence à un plongement de taille 384 !
        embedding = output.mean(dim=1)  # Moyenne sur la dimension des tokens (dimension sequence_length) pour avoir la représentation de la séquence
        embeddings.append(embedding)
    
    return torch.cat(embeddings, dim=0)

# %%
from torch.utils.data import Dataset
class ContrastiveDatasetWithNegatives(Dataset):
    def __init__(self, questions, positive_passages, negative_passages, tokenizer, model ,batch_size_encoder = 512 ,device = DEVICE):
        self.questions = questions
        self.positive_passages = positive_passages
        self.negative_passages = negative_passages
        
        self.tokenizer = tokenizer
        self.model = model
        self.device = device 
        self.batch_size_encoder = batch_size_encoder  
        

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        question = self.questions[idx]
        #print(question)
        positive_passage = self.positive_passages[idx]
        #print(type(positive_passage))
        negative_passage = self.negative_passages[idx]
        #print(type(negative_passage))

    
        question_embedding = encode_sequences([question], self.tokenizer, self.model, self.device)
        positive_passage_embedding = encode_sequences([positive_passage], self.tokenizer, self.model, self.device )
        negative_passage_embedding = encode_sequences([negative_passage], self.tokenizer, self.model, self.device)

        # Embeddings
        return {
            "question_embedding": question_embedding.squeeze(0),  # Remove batch dimension
            "positive_passage_embedding": positive_passage_embedding.squeeze(0),
            "negative_passage_embedding": negative_passage_embedding.squeeze(0),
        }

# %%
dataset = ContrastiveDatasetWithNegatives(questions_string , positives_string , negatives_string ,emb_tokenizer, emb_model , batch_size_encoder= 64 )

# %%
emb = dataset.__getitem__(0)

# %%
print(emb['positive_passage_embedding'].shape)
# Out:
# torch.Size([384])

# %%
from torch.nn import TripletMarginLoss
from torch.optim import AdamW
from torch.utils.data import DataLoader
from tqdm import tqdm  # Import tqdm for progress bars

# Define the optimizer
optimizer = AdamW(emb_model.parameters(), lr=5e-5)  # Adjust the learning rate as needed
triplet_loss = TripletMarginLoss(margin=1.0)

# Training loop
for epoch in range(3):  # Number of epochs
    print(f"Epoch {epoch+1}")
    
    # Wrap the DataLoader with tqdm for a progress bar
    data_loader = DataLoader(dataset, batch_size=32, shuffle=True)
    progress_bar = tqdm(data_loader, desc=f"Training Epoch {epoch+1}", unit="batch")
    
    for batch in progress_bar:
        optimizer.zero_grad()

        # Retrieve embeddings
        question_embeddings = batch["question_embedding"]
        positive_passage_embeddings = batch["positive_passage_embedding"]
        negative_passage_embeddings = batch["negative_passage_embedding"]

        # Compute the triplet loss
        loss = triplet_loss(question_embeddings, positive_passage_embeddings, negative_passage_embeddings)
        loss.backward()
        optimizer.step()

        # Update the progress bar with the current loss
        progress_bar.set_postfix(loss=loss.item())

    print(f"Epoch {epoch+1} completed. Loss: {loss.item()}")
# Out:
# Training Epoch 1: 100%|██████████| 155/155 [05:24<00:00,  2.09s/batch, loss=0.135]
# Epoch 1 completed. Loss: 0.1353560835123062
# Epoch 2
# Training Epoch 2: 100%|██████████| 155/155 [05:27<00:00,  2.11s/batch, loss=0.00647]
# Epoch 2 completed. Loss: 0.006467193365097046
# Epoch 3
# Training Epoch 3: 100%|██████████| 155/155 [05:23<00:00,  2.09s/batch, loss=0]
# Epoch 3 completed. Loss: 0.0

# %%
import torch

# Save the model weights after training
torch.save(emb_model.state_dict(), "fine_tuned_model_weights.pth")
print("Model weights saved.")
# Out:
# Model weights saved.

# %%
print(torch.cuda.memory_summary(device="cuda", abbreviated=True))

# %%
# Load the saved weights
emb_model.load_state_dict(torch.load("fine_tuned_model_weights.pth"))
print("Model weights loaded.")
# Out:
# Model weights loaded.

# %%
# TODO
passages = texts['text'].tolist()
questions = questions_val['question'].tolist()

passage_embed = encode_sequences(passages, emb_tokenizer, emb_model )
# END TODO
top_passages = retrieve_passages(questions_train['question'].tolist(), passage_embed, 7, emb_tokenizer, emb_model)

# %% [markdown]
# #### 3.1.4 Graphique (3 points)
# Affichez maintenant un graphique de vos résultats de la question précédente en mettant à l'axe des x la valeur de $k$ et à l'axe des y la valeur de la précision et du rappel. Quel est le nombre optimal de passages à passer au modèle en vous basant sur le recall@k et precision@k ? Pourquoi ?

# %%
# TODO
top_passages = retrieve_passages(questions_train['question'].tolist(), passage_embed, 7, emb_tokenizer, emb_model)
top_ground_truth = questions_val['text_ids'].apply(lambda x: [int(num) for num in x.strip('[]').split()]).to_list()
print(type(top_ground_truth[0][0]))

recall  = []
precision = []
for k in range(1,6) : 
    top_passages = retrieve_passages(questions, passage_embed, k, emb_tokenizer, emb_model)
    recall.append(compute_recall_at_k(top_ground_truth, top_passages))
    precision.append(compute_precision_at_k(top_ground_truth, top_passages))


plt.plot(range(1,6), recall, marker='o', color='b', label='Recall@k')
plt.plot(range(1,6), precision, marker='x', color='r', label='Precision@k')
plt.xlabel('k (Number of passages consider)')
plt.ylabel('Metric value')
plt.title('Recall and Precision at different k values')
plt.legend()
plt.grid(True)
plt.show()

# END TODO
# Out:
# <class 'int'>

# %%
top_passages
# Out:
# [[10039, 314, 4059, 6877, 6660],
#  [8049, 7140, 9286, 13054, 7647],
#  [11620, 271, 5520, 3105, 8460],
#  [13306, 5363, 9320, 9353, 10830],
#  [8473, 11162, 12586, 5228, 1485],
#  [2327, 5883, 7383, 4146, 1696],
#  [12254, 8676, 5661, 10546, 1413],
#  [5363, 13306, 9320, 9353, 13153],
#  [11599, 7771, 5883, 2327, 4129],
#  [2787, 8395, 4074, 9992, 596],
#  [3634, 5414, 8800, 12634, 3820],
#  [3806, 11050, 1523, 3910, 10278],
#  [4117, 10518, 8625, 3186, 704],
#  [10602, 10128, 10047, 8886, 6712],
#  [7002, 8928, 6717, 8397, 8734],
#  [7628, 12724, 9319, 2694, 2764],
#  [12017, 7309, 9919, 359, 13017],
#  [5297, 6960, 5152, 8887, 10555],
#  [9971, 5227, 3907, 10111, 1615],
#  [4619, 6218, 8722, 12344, 12066],
#  [4181, 3608, 8063, 7454, 7288],
#  [4108, 4802, 8256, 10053, 12779],
#  [8248, 4788, 4530, 12555, 5475],
#  [11477, 10094, 1009, 5513, 5790],
#  [6262, 5339, 4108, 2924, 2477],
#  [10650, 6051, 1138, 1876, 8321],
#  [391, 7232, 6170, 5793, 8451],
#  [8340, 1705, 9652, 3895, 1442],
#  [9299, 3109, 714, 8875, 13100],
#  [11345, 7262, 11742, 5582, 3310],
#  [474, 3513, 7220, 2464, 6442],
#  [9856, 4193, 11525, 10475, 7939],
#  [9387, 1479, 1457, 10498, 2083],
#  [10221, 3988, 1536, 1207, 2589],
#  [10564, 1415, 11338, 6174, 4460],
#  [440, 1326, 6282, 11332, 7337],
#  [8870, 8397, 7073, 11842, 7127],
#  [4146, 259, 3658, 10389, 311],
#  [6780, 6337, 11805, 7447, 3246],
#  [296, 10195, 3467, 5068, 11609],
#  [4768, 5837, 2316, 13222, 3895],
#  [9831, 3040, 3295, 10596, 3246],
#  [10298, 12337, 7989, 12874, 6834],
#  [3975, 6916, 11489, 12684, 4146],
#  [1424, 2688, 9348, 12401, 3787],
#  [11895, 1274, 10682, 2665, 10285],
#  [4612, 1548, 12106, 12650, 5361],
#  [7999, 2789, 3046, 2232, 10865],
#  [9183, 12201, 7096, 1956, 5389],
#  [11145, 10165, 10490, 9821, 8598],
#  [7573, 1138, 12725, 7763, 11964],
#  [2039, 1590, 5566, 2192, 6580],
#  [9789, 7035, 10227, 462, 12881],
#  [12717, 4517, 2344, 596, 6491],
#  [8397, 3684, 5204, 311, 11139],
#  [10963, 8480, 12034, 8896, 12800],
#  [1055, 13142, 3024, 5639, 5500],
#  [9629, 8323, 4684, 8895, 5146],
#  [8598, 12671, 8308, 11135, 7265],
#  [1508, 7985, 11155, 11641, 10417],
#  [4802, 11301, 8854, 12584, 3434],
#  [2623, 10278, 4986, 1523, 6218],
#  [12769, 6221, 5339, 2885, 311],
#  [7912, 561, 2964, 4688, 22],
#  [9347, 4858, 3825, 1113, 12539],
#  [9995, 3163, 4273, 8345, 12844],
#  [6614, 3576, 11667, 7393, 714],
#  [11985, 10426, 2874, 1389, 7747],
#  [10366, 5326, 8611, 11637, 2106],
#  [4359, 4553, 1237, 1243, 2807],
#  [5577, 9387, 5546, 5621, 4574],
#  [5824, 8430, 971, 9715, 13185],
#  [8043, 10166, 10874, 5494, 12666],
#  [864, 8127, 2468, 5437, 656],
#  [2078, 5197, 10428, 5747, 10136],
#  [8334, 1523, 6218, 5116, 7217],
#  [12195, 461, 3236, 9556, 10475],
#  [7683, 5506, 10583, 5149, 9329],
#  [12775, 2332, 623, 11416, 3995],
#  [12084, 7210, 9454, 6898, 12586],
#  [13065, 3484, 2847, 966, 9592],
#  [175, 8032, 2307, 8010, 10802],
#  [4982, 6034, 808, 1150, 6357],
#  [10709, 1148, 6915, 1009, 2517],
#  [5618, 3787, 2598, 5042, 803],
#  [4967, 8049, 13176, 11279, 9763],
#  [6925, 11633, 8185, 5980, 12560],
#  [10295, 350, 9321, 7874, 11241],
#  [11045, 9518, 2803, 4732, 10216],
#  [3291, 4490, 6797, 1710, 13197],
#  [10211, 1123, 13069, 12423, 11496],
#  [6191, 9811, 7516, 3085, 8485],
#  [4040, 9034, 2657, 5621, 8484],
#  [9505, 11784, 2088, 10134, 3076],
#  [12983, 1026, 5621, 11281, 2466],
#  [12075, 10430, 2854, 2356, 8253],
#  [2449, 11778, 8918, 5005, 7904],
#  [1748, 12446, 311, 11163, 10136],
#  [13035, 592, 7564, 11013, 13144],
#  [9074, 10769, 8260, 9454, 10544],
#  [1523, 11154, 1550, 5023, 3910],
#  [11741, 8567, 6311, 7427, 5770],
#  [13062, 5185, 7977, 2662, 10136],
#  [3733, 4279, 12880, 9359, 3410],
#  [803, 1489, 4967, 33, 3986],
#  [10508, 11869, 9324, 4608, 7548],
#  [11487, 8354, 13054, 1462, 9058],
#  [9343, 12994, 8196, 7726, 6601],
#  [10714, 467, 4533, 3512, 4495],
#  [3295, 7256, 12888, 3174, 12143],
#  [3334, 9246, 6996, 4759, 10302],
#  [6839, 6664, 12816, 11613, 2775],
#  [1481, 9448, 8514, 6593, 12488],
#  [3375, 5280, 12926, 10603, 6973],
#  [12785, 2511, 4442, 345, 7537],
#  [7881, 11682, 704, 5976, 12983],
#  [5597, 3200, 5572, 8153, 6382],
#  [498, 1742, 1523, 9973, 7824],
#  [9247, 7904, 1400, 6739, 12881],
#  [12602, 9469, 971, 4025, 5824],
#  [6552, 9868, 12450, 9815, 9981],
#  [3475, 1134, 5499, 12283, 11774],
#  [6470, 2057, 10377, 9320, 13306],
#  [8752, 8598, 3576, 9387, 11324],
#  [9485, 7969, 753, 5720, 2797],
#  [1523, 6218, 10440, 6871, 7824],
#  [6910, 5536, 6646, 4731, 8996],
#  [2663, 10968, 1520, 10992, 11459],
#  [7071, 3552, 4298, 7337, 10211],
#  [10063, 8947, 10474, 12995, 7657],
#  [8959, 697, 11134, 2694, 7030],
#  [12937, 2003, 8996, 4424, 1757],
#  [5580, 3359, 7044, 10140, 11173],
#  [11008, 5857, 4688, 22, 485],
#  [1134, 3699, 2683, 4613, 770],
#  [5219, 12488, 5580, 3359, 2525],
#  [6049, 9720, 12257, 2940, 12942],
#  [12452, 9290, 9250, 6069, 9273],
#  [6644, 9101, 5546, 7644, 3363],
#  [12334, 6100, 12994, 470, 7230],
#  [4118, 1452, 187, 7229, 8377],
#  [2088, 4840, 10285, 5374, 6244],
#  [6278, 1623, 10298, 3896, 4007],
#  [4058, 4731, 11024, 12352, 12579],
#  [18, 7855, 1378, 5582, 1876],
#  [7552, 8397, 13300, 3076, 11139],
#  [4449, 310, 10414, 2314, 10971],
#  [1924, 4436, 5634, 12953, 7415],
#  [2884, 8029, 7540, 3128, 6126],
#  [4997, 2554, 9594, 6111, 13103],
#  [10820, 6108, 3256, 3945, 11653],
#  [10954, 8223, 9820, 1719, 3895],
#  [2397, 4056, 5485, 2746, 4572],
#  [4013, 7588, 5091, 10594, 1955],
#  [9435, 10167, 3544, 5475, 11772],
#  [6911, 7337, 5981, 1500, 3071],
#  [10211, 2083, 3896, 10556, 10823],
#  [200, 10355, 6539, 2694, 12680],
#  [259, 8168, 3310, 4699, 9974],
#  [3229, 1124, 2048, 36, 789],
#  [497, 6259, 443, 10313, 5177],
#  [8530, 2069, 5940, 2682, 12114],
#  [5889, 6451, 3341, 12377, 3916],
#  [11040, 2670, 774, 9521, 2882],
#  [12228, 2909, 5780, 8551, 4109],
#  [13053, 3879, 540, 10231, 6320],
#  [9180, 8458, 4030, 8049, 12323],
#  [497, 9685, 8767, 3515, 704],
#  [3299, 9308, 4654, 5430, 11461],
#  [7683, 6454, 1924, 3484, 9698],
#  [11558, 1244, 8851, 785, 5901],
#  [10278, 9661, 1500, 1222, 8722],
#  [5159, 8333, 7019, 13201, 2477],
#  [5794, 8226, 6216, 710, 689],
#  [6268, 11734, 5996, 3950, 9195],
#  [9090, 10004, 4083, 12364, 140],
#  [8956, 12235, 10172, 8022, 885],
#  [1595, 10822, 2003, 7975, 4350],
#  [1409, 5802, 12855, 7677, 7632],
#  [305, 1775, 12944, 3500, 3464],
#  [9731, 6863, 10904, 6529, 3450],
#  [9881, 886, 10579, 1772, 3657],
#  [12505, 12450, 6673, 8538, 10556],
#  [410, 8598, 11134, 9387, 5107],
#  [1256, 11246, 6447, 2908, 7620],
#  [4303, 6229, 10793, 12450, 10184],
#  [10824, 554, 2950, 6737, 11208],
#  [12374, 8641, 5361, 8694, 5747],
#  [937, 8635, 6788, 11730, 8042],
#  [4267, 156, 10252, 1619, 7111],
#  [10002, 9401, 6726, 5204, 10428],
#  [3384, 8965, 13232, 11693, 3199],
#  [10287, 5885, 5532, 3618, 1219],
#  [5049, 4158, 3227, 4146, 499],
#  [12412, 8891, 10881, 3640, 2868],
#  [5897, 5974, 12318, 10549, 6984],
#  [7786, 122, 5236, 7863, 9450],
#  [9491, 2771, 4967, 11279, 1500],
#  [449, 2514, 1648, 6808, 7975],
#  [12535, 3434, 11301, 2021, 596],
#  [12575, 12740, 1138, 8875, 5773],
#  [10642, 9324, 4948, 7908, 4080],
#  [12679, 3648, 11764, 4459, 62],
#  [4204, 7124, 8625, 9252, 1138],
#  [12826, 4254, 6048, 6187, 6460],
#  [5189, 5450, 3401, 9890, 11526],
#  [9737, 1329, 11626, 3427, 3310],
#  [5148, 11260, 11634, 12457, 313],
#  [10493, 2131, 507, 664, 6159],
#  [9199, 3735, 1588, 10682, 10285],
#  [71, 8990, 7377, 1977, 10251],
#  [518, 3901, 1752, 9335, 12563],
#  [246, 3920, 2102, 7952, 12179],
#  [3735, 9199, 7577, 12684, 3895],
#  [11595, 8842, 3059, 11065, 3920],
#  [8098, 3862, 5184, 12956, 908],
#  [3488, 3182, 1910, 13022, 10191],
#  [760, 8587, 9754, 10591, 2057],
#  [11964, 1404, 9387, 4892, 1772],
#  [2688, 1424, 9348, 12401, 7891],
#  [8484, 1138, 1134, 2003, 5164],
#  [5479, 2142, 1266, 3775, 2526],
#  [6050, 1019, 10678, 9111, 4123],
#  [10549, 200, 2521, 10044, 5573],
#  [11931, 8771, 840, 2857, 12357],
#  [9075, 6803, 11534, 2856, 6071],
#  [5368, 3463, 9243, 1252, 9989],
#  [3291, 6797, 1710, 4490, 13197],
#  [7534, 4007, 6739, 220, 12522],
#  [2441, 1609, 9193, 5747, 596],
#  [9270, 4844, 2356, 5181, 2578],
#  [9778, 3788, 6986, 3912, 9839],
#  [2044, 1026, 36, 12212, 12238],
#  [2132, 732, 6988, 7194, 375],
#  [4458, 12239, 1680, 6868, 6572],
#  [2761, 13213, 2372, 4007, 12239],
#  [2153, 6512, 2698, 7262, 2284],
#  [3525, 12120, 13214, 11979, 6842],
#  [2754, 1599, 11348, 12215, 1473],
#  [2168, 6532, 9840, 8506, 8620],
#  [937, 8635, 6788, 11730, 8042],
#  [6550, 697, 3448, 3227, 5204],
#  [2056, 12247, 912, 9230, 13170],
#  [2759, 1173, 5634, 4613, 10072],
#  [12835, 13300, 11742, 311, 5747],
#  [451, 10235, 4309, 8749, 10191],
#  [8309, 7212, 5114, 8256, 1931],
#  [2790, 4801, 1793, 2480, 5901],
#  [11438, 10017, 12623, 4201, 9189],
#  [778, 9443, 4517, 7684, 7004],
#  [7748, 8336, 4735, 2833, 4688],
#  [3246, 11805, 12764, 1538, 2345],
#  [5859, 11303, 13022, 8201, 9037],
#  [1717, 828, 1547, 897, 8627],
#  [575, 8415, 4647, 284, 926],
#  [3310, 596, 8491, 5889, 3122],
#  [5319, 12685, 6753, 6243, 4785],
#  [1388, 7004, 3892, 116, 618],
#  [699, 10795, 459, 5298, 267],
#  [11113, 1873, 6333, 5414, 6694],
#  [8703, 7054, 10693, 12664, 10872],
#  [6296, 9870, 7328, 1953, 10998],
#  [509, 10128, 11808, 6804, 9016],
#  [8049, 7084, 11158, 6217, 71],
#  [949, 8273, 9272, 12899, 12122],
#  [5969, 11260, 8424, 12065, 11987],
#  [7470, 9255, 4688, 4572, 9763],
#  [7390, 5731, 5083, 12369, 12294],
#  [12122, 5764, 5782, 5422, 9272],
#  [700, 9732, 5417, 4381, 12603],
#  [13014, 6519, 4871, 1857, 2466],
#  [3391, 11025, 2583, 10116, 11895],
#  [10998, 274, 8842, 246, 3920],
#  [809, 6196, 440, 8049, 7647],
#  [8928, 9450, 4183, 5096, 2200],
#  [9082, 8397, 3787, 1500, 11742],
#  [9215, 4323, 10773, 10755, 9398],
#  [5137, 4255, 5513, 200, 8231],
#  [12036, 1115, 13022, 5582, 6660],
#  [11110, 2742, 8616, 9927, 8320],
#  [6707, 8318, 5313, 5938, 6513],
#  [10302, 6178, 5870, 9373, 6374],
#  [4964, 7227, 5431, 6419, 3395],
#  [1855, 3617, 7939, 3573, 6596],
#  [10855, 12897, 4560, 3876, 12101],
#  [5292, 12101, 11258, 4632, 9228],
#  [5739, 13255, 5500, 5933, 2102],
#  [9873, 6739, 3449, 12953, 7415],
#  [3861, 9213, 6354, 7237, 6349],
#  [5732, 2154, 5064, 8443, 13225],
#  [6381, 5931, 198, 12974, 5841],
#  [3122, 10654, 10242, 11185, 5361],
#  [6346, 7478, 10116, 11895, 13170],
#  [13132, 2874, 1326, 9814, 11332],
#  [1922, 10278, 12321, 1138, 4076],
#  [10968, 4007, 11626, 3076, 345],
#  [5566, 7586, 6918, 2723, 11626],
#  [4878, 1379, 598, 10682, 12861],
#  [9438, 13173, 595, 12174, 6904],
#  [8279, 10854, 1857, 9265, 5824],
#  [1652, 4032, 3438, 6088, 12042],
#  [627, 11882, 9839, 8755, 3910],
#  [5166, 11445, 538, 11742, 1347],
#  [49, 2986, 11355, 4004, 10655],
#  [10166, 8043, 10874, 5494, 8358],
#  [768, 1167, 12115, 8548, 2354],
#  [10716, 10584, 10136, 1247, 9826],
#  [7824, 6218, 7217, 6195, 1377],
#  [6185, 7206, 8416, 12277, 7099],
#  [894, 10395, 3250, 9352, 10784],
#  [9432, 25, 1530, 12912, 2730],
#  [3737, 13003, 7559, 7321, 2737],
#  [7955, 12000, 9193, 11742, 5889],
#  [8774, 251, 5232, 8126, 886],
#  [11119, 8777, 10360, 2587, 3307],
#  [9746, 1358, 11042, 754, 10403],
#  [9152, 563, 9955, 12563, 83],
#  [11576, 9119, 11074, 12291, 10443],
#  [9324, 4948, 4080, 10642, 3122],
#  [4313, 4528, 5582, 601, 9165],
#  [12236, 2161, 227, 11260, 12872],
#  [5562, 3269, 9523, 2403, 6163],
#  [11217, 68, 2386, 10899, 641],
#  [2548, 6179, 1601, 5709, 11706],
#  [2940, 8625, 3122, 13300, 4572],
#  [12819, 13057, 44, 7409, 7397],
#  [3204, 9609, 4222, 9952, 8965],
#  [9859, 8577, 9291, 5361, 10715],
#  [10152, 1769, 10809, 3297, 6468],
#  [8734, 5313, 4688, 22, 9454],
#  [2263, 11133, 704, 13022, 3199],
#  [12088, 8462, 2998, 6495, 3172],
#  [5509, 5473, 12693, 2937, 1416],
#  [11881, 8112, 5573, 1499, 1347],
#  [3502, 1465, 8408, 8820, 4318],
#  [1065, 11260, 2378, 2713, 8722],
#  [2448, 2173, 4840, 12602, 5823],
#  [7975, 8515, 2571, 3865, 1876],
#  [11767, 6079, 2363, 11467, 3076],
#  [389, 2658, 3175, 3283, 7379],
#  [12729, 1596, 4133, 5518, 4945],
#  [12594, 5724, 548, 9144, 8727],
#  [6491, 12291, 3786, 12361, 404],
#  [2981, 6449, 5968, 11402, 191],
#  [9834, 12380, 11697, 5541, 11461],
#  [8625, 13250, 7881, 636, 697],
#  [5216, 8940, 5204, 12196, 826],
#  [273, 3702, 7035, 322, 2101],
#  [13137, 708, 12798, 1523, 6218],
#  [5902, 11449, 493, 7274, 1500],
#  [11098, 2482, 3810, 6367, 5129],
#  [7294, 13311, 10994, 2003, 6916],
#  [2870, 5122, 2208, 9418, 4994],
#  [406, 11733, 4366, 6690, 10177],
#  [4261, 1138, 2941, 12829, 11607],
#  [1567, 1169, 9850, 1028, 2725],
#  [7586, 6918, 2723, 5566, 10956],
#  [6752, 11873, 3518, 1576, 3316],
#  [13300, 9311, 9442, 5946, 10161],
#  [1055, 5639, 5500, 3024, 13142],
#  [12563, 101, 10278, 7337, 1523],
#  [3236, 312, 7677, 10379, 11139],
#  [715, 3978, 5466, 5190, 1284],
#  [311, 4967, 6382, 11279, 1500],
#  [10909, 8447, 11359, 8452, 3892],
#  [7337, 3276, 3895, 9398, 596],
#  [10297, 11515, 4654, 6793, 11039],
#  [4807, 8206, 7167, 12337, 92],
#  [10851, 8263, 2398, 8168, 10556],
#  [1354, 6539, 8121, 2477, 7337],
#  [1924, 1462, 7579, 1323, 3498],
#  [10073, 8625, 311, 6338, 4183],
#  [11999, 5994, 8996, 10715, 1595],
#  [7214, 11474, 5429, 11607, 7337],
#  [4747, 6143, 8428, 13022, 4483],
#  [1701, 7207, 11472, 9124, 6129],
#  [2798, 789, 1638, 249, 9628],
#  [2228, 777, 12909, 12403, 11518],
#  [8225, 9484, 11774, 4774, 10693],
#  [2302, 830, 932, 10672, 6567],
#  [8543, 5341, 6799, 5100, 8996],
#  [4076, 8293, 7629, 12563, 6871],
#  [704, 5605, 8598, 10421, 9301],
#  [6416, 2375, 11608, 5513, 5212],
#  [3186, 1894, 11345, 11519, 576],
#  [4587, 3158, 1924, 8312, 7415],
#  [12204, 12957, 13164, 7515, 8363],
#  [9013, 10137, 3433, 11176, 9570],
#  [10191, 1280, 4080, 8533, 6223],
#  [5394, 3563, 5958, 7925, 6502],
#  [4079, 11038, 7121, 37, 11979],
#  [1613, 13083, 2468, 11392, 6734],
#  [3865, 11135, 9621, 3576, 10979],
#  [22, 4688, 6668, 2620, 2346],
#  [3147, 12278, 5542, 6633, 10291],
#  [3506, 2134, 7226, 8256, 10475],
#  [2545, 4490, 7293, 4274, 8598],
#  [9803, 13055, 8513, 4209, 7818],
#  [48, 5556, 5538, 1473, 65],
#  [4140, 12506, 10443, 2591, 6207],
#  [12810, 7509, 12986, 9805, 1857],
#  [466, 13054, 8049, 2477, 4125],
#  [4921, 1490, 188, 11974, 2418],
#  [9920, 4047, 511, 9225, 4337],
#  [6387, 4520, 11602, 8161, 300],
#  [8448, 8043, 3776, 8605, 3462],
#  [12781, 3912, 11875, 1673, 12428],
#  [9839, 1086, 8999, 3857, 4398],
#  [9393, 7975, 261, 7029, 3391],
#  [12305, 4766, 5851, 12743, 13143],
#  [12731, 5039, 2589, 7091, 259],
#  [1924, 1462, 7579, 1323, 3498],
#  [1494, 1347, 10059, 8220, 7337],
#  [6951, 2048, 4545, 1134, 11909],
#  [1673, 3912, 10142, 4032, 10895],
#  [12525, 12172, 1561, 11260, 11926],
#  [1745, 883, 8835, 10421, 720],
#  [11570, 7337, 1523, 10475, 9454],
#  [1186, 3308, 5986, 7266, 7955],
#  [11940, 10154, 4247, 5200, 6735],
#  [8085, 1523, 7337, 11154, 5023],
#  [9941, 5746, 4294, 1587, 4725],
#  [6688, 1103, 12291, 950, 840],
#  [4153, 5254, 12129, 6807, 8442],
#  [4288, 7331, 2646, 10152, 440],
#  [2166, 2218, 13067, 3985, 5043],
#  [9192, 6965, 780, 6218, 7824],
#  [1315, 7172, 4101, 2500, 11772],
#  [183, 7078, 13286, 12881, 12468],
#  [8062, 8834, 12861, 3207, 11166],
#  [1179, 124, 12760, 3046, 5747],
#  [8383, 964, 2406, 4705, 3895],
#  [8625, 10490, 3199, 11626, 6821],
#  [12894, 12915, 5558, 1036, 12222],
#  [259, 12390, 10475, 1971, 4237],
#  [11154, 11300, 7337, 1523, 4076],
#  [1523, 8722, 11154, 128, 10033],
#  [9256, 1131, 6641, 11380, 4146],
#  [48, 5556, 5538, 1473, 65],
#  [8114, 3750, 10251, 5148, 7347],
#  [8397, 5969, 11185, 7337, 8924],
#  [8894, 3270, 12821, 5299, 3863],
#  [7022, 3715, 2508, 8498, 4412],
#  [8790, 4781, 9904, 10602, 5204],
#  [9528, 8049, 466, 7647, 12666],
#  [7893, 4103, 8886, 4615, 6036],
#  [8595, 6877, 11965, 7657, 9914],
#  [3740, 1615, 12874, 11527, 3500],
#  [9556, 12074, 3594, 9826, 11139],
#  [4324, 5007, 10689, 5818, 6722],
#  [7147, 10498, 12215, 2885, 13013],
#  [12609, 11311, 7824, 302, 1222],
#  [10299, 2950, 7157, 10351, 3199],
#  [9138, 2587, 6799, 5546, 6346],
#  [792, 7824, 12066, 605, 1523],
#  [10582, 6318, 5218, 7211, 11718],
#  [5308, 667, 3952, 7463, 7690],
#  [4447, 1455, 8088, 5564, 2797],
#  [8008, 8027, 8789, 11062, 12391],
#  [7326, 10367, 832, 103, 9661],
#  [8210, 12684, 311, 4548, 11972],
#  [13067, 7337, 7955, 3986, 128],
#  [6786, 9413, 5564, 1802, 7379],
#  [9252, 4340, 3945, 8625, 12495],
#  [4608, 7763, 1979, 2587, 11139],
#  [6912, 7090, 7240, 1784, 8553],
#  [9218, 1523, 71, 7824, 10440],
#  [1523, 4152, 5023, 10278, 12563],
#  [5554, 3313, 13049, 5635, 3240],
#  [11988, 7830, 2251, 10261, 2551],
#  [8568, 9132, 6338, 5758, 11484],
#  [8129, 13229, 11960, 2607, 3696],
#  [4342, 6960, 13076, 3351, 5429],
#  [8399, 2261, 3127, 1134, 8397],
#  [1351, 4598, 8424, 13269, 8264],
#  [10139, 6951, 6922, 5634, 3310],
#  [2079, 6535, 12832, 2571, 13001],
#  [158, 5801, 13171, 12676, 6402],
#  [6802, 3197, 12403, 12684, 596],
#  [8188, 10599, 10936, 6477, 11597],
#  [9184, 7603, 3046, 4893, 5641],
#  [5509, 5473, 12693, 2937, 1416],
#  [8423, 11148, 5865, 5966, 9049],
#  [193, 7847, 1134, 8397, 3475],
#  [6237, 4403, 12588, 11157, 5341],
#  [380, 8297, 2634, 1565, 7418],
#  [1523, 6218, 5023, 8334, 4874],
#  [9720, 9044, 11013, 681, 2046],
#  [5969, 11260, 12684, 4076, 11139],
#  [4629, 9373, 6865, 10409, 6178],
#  [12635, 2846, 11747, 10621, 3310],
#  [386, 10051, 5398, 9608, 3351],
#  [5027, 2319, 847, 10074, 5927],
#  [4860, 4525, 4345, 5982, 982],
#  [12334, 4616, 7779, 3920, 6847],
#  [937, 8635, 8042, 7498, 9398],
#  [8709, 3175, 10537, 6019, 13221],
#  [6867, 1001, 2838, 10927, 11157],
#  [13016, 9450, 9398, 1443, 10579],
#  [1728, 4761, 3208, 6130, 9039]]

# %% [markdown]
# ### 3.2 RAG figé avec FAISS (14 points)

# %% [markdown]
# Maintenant on vous demande d'utiliser FAISS pour l'indexation des plongements des passages.
#
# [FAISS (Facebook AI Similarity Search)](https://ai.meta.com/tools/faiss/) est une bibliothèque open-source développée par Meta pour la recherche de similarité rapide sur des vecteurs denses, comme des embeddings de textes ou d'images. Elle est optimisée pour gérer de grands volumes de données en haute dimension et peut être accélérée avec des GPU. FAISS est largement utilisée pour des systèmes de recommandation ou la recherche d'information à grande échelle. Pour plus de détails, veuillez consulter  [le tutoriel sur Moodle](https://moodle.polymtl.ca/course/view.php?id=2813).

# %% [markdown]
# #### 3.2.1 Initialisez l'indexation FAISS avec les plongements des passages (2 points)
#
# Utilisez les plongements des passages générés au niveau de la question 3.1.1 et indexez-les avec FAISS. Vérifiez que le nombre de plongements dans l'objet FAISS est bien le même que le nombre de passages. N'oubliez pas qu'on veut une indexation basée sur la similarité cosinus.

# %%
# TODO
passage_embeddings = passage_embed.cpu().numpy()

faiss.normalize_L2(passage_embeddings) #  normalisation des vecteurs pour l'approche similarité cosinus
d = passage_embeddings.shape[1]
index = faiss.IndexFlatIP(d)  # index Faiss basé sur le produit "scalaire" -> la recherche donnera les k documents les plus similaires basé sur le produit scalaire entre le vecteur d'entrée et les vecteurs de passage_embeddings
index.add(passage_embeddings)

assert index.ntotal == passage_embeddings.shape[0], "Le nombre de plongements dans l'objet FAISS est le même que le nombre de passages."
# END TODO

# %% [markdown]
# #### 3.2.2 Récupération des passages avec FAISS (4 points)
#
# Implémentez la fonction _'retrieve_passages_faiss'_ qui retourne les indices des $k$ passages les plus similaires pour une question à l'aide d'un indexation FAISS

# %%
def retrieve_passages_faiss(questions: list, vector_index: faiss.IndexFlatL2, k: int, embedding_model_tokenizer, embedding_model):
    """
    Retourne les k passages les plus pertinents pour chaque question passée en paramètre

    Paramètres:
    questions       : Les questions pour lesquelles on cherche les passages les plus pertinents
    vector_index    : L'objet d'indexation FAISS
    k               : le nombre de passages à retourner
    tokenizer       : Segmenteur du modèle de plongements
    model           : Modèle de plongements

    Retourne:
    Les indices des k passages les plus pertinents pour la question
    """
    # TODO
    question_embeddings = encode_sequences(questions, embedding_model_tokenizer, embedding_model)
    
    # Normalisation
    question_embeddings = question_embeddings.cpu().numpy()
    faiss.normalize_L2(question_embeddings)
    
    _, top_k_indices = vector_index.search(question_embeddings, k)  # indices de dimension (len(questions), k)
    
    return top_k_indices
    # END TODO

# %% [markdown]
# #### 3.2.3 Exécution de FAISS (4 points)
#
# Exécutez maintenant la fonction _"retrieve_passages_faiss"_ pour récupérer les bons passages pour les questions du jeu de validation avec votre k optimal.

# %%
# TODO
print(retrieve_passages_faiss(questions, index, 3, emb_tokenizer, emb_model))
# END TODO
# Out:
# [[10039  1885  4270]
#  [ 8865  5333  2651]
#  [11620  4618 10382]
#  ...
#  [ 2838  1001  7523]
#  [13016 10021 11171]
#  [ 1728  5978  6130]]

# %% [markdown]
# #### 3.2.4 Calculez les métriques Precision@K et Rappel@K pour les passages retrouvés avec FAISS avec votre k optimal (2 points)

# %%
# TODO
top_passages = retrieve_passages_faiss(questions, index, 3, emb_tokenizer, emb_model)
print(compute_recall_at_k(top_ground_truth, top_passages))
print(compute_precision_at_k(top_ground_truth, top_passages))
# END TODO
# Out:
# 0.6069999999999997
# 0.5619999999999998

# %% [markdown]
# #### 3.2.5 Quelle remarque pouvez-vous faire sur l'utilisation de FAISS en termes de passages retrouvés, de temps d'exécution et de tout autre élément qui vous semble approprié ? (2 points)

# %% [markdown]
# > Réponse

# %% [markdown]
# ### 3.3 Génération des réponses (5 points)
#
# Générez maintenant les réponses des questions sur l'ensemble de validation avec les passages récupérés. Pour générer les réponses, vous devez concaténer les passages pertinents avec la question et donner le tout au modèle de génération. Faites-le sur l'ensemble du jeu de validation. Pour la méthode, vous avez le choix entre les passages retrouvés avec FAISS ou manuellement (avec votre propre implémentation). Faites cela pour toutes les valeurs de $k$: (1, 2, 3 et 4).

# %%
# TODO

# Générez les prompts
k_values = [1, 2, 3, 4]
prompts_k = {}  # Dictionnaire pour stocker les prompts par valeur de k

for k in k_values:
    prompts_k[k] = []  # Initialiser une liste pour chaque k
    faiss_passages = retrieve_passages_faiss(questions, index, k, emb_tokenizer, emb_model)  
    help_instruction = "Give a concise answer in a few words to the question. You can help yourself by using the above informations."

    # Boucle sur chaque question et ses passages associés
    for i, passages_id in enumerate(faiss_passages):
        passages = []

        # Récupérer les textes des passages associés à la question actuelle
        for passage_id in passages_id:
            passage_text = texts[texts['id'] == passage_id]['text'].iloc[0]
            passages.append(passage_text)

        # Construire le contexte complet et l'ajouter à la liste des prompts pour k
        context_string = (
            f"Question : {questions[i]}\n"
            f"Relevant informations :\n"
            + "\n".join([f"{j+1}. {passage}" for j, passage in enumerate(passages)]) +
            f"\n{help_instruction}"
        )
        prompts_k[k].append(context_string)
        
# END TODO

# %% [markdown]
# Affichez un exemple d'invite (prompt) qui sera envoyé au modèle de génération

# %%
# TODO

# Affichez un exemple d'invite
print(prompts_k[1][0])
print(prompts_k[2][0])
print(prompts_k[3][0])
print(prompts_k[4][0])

# END TODO
# Out:
# Question : What is the effect of the M201V variant of CYSLTR2 on responsiveness to LTD4?
# Relevant informations :
# 1.  Polymorphism in the CYSLTR2 gene has been associated with the inheritance of asthma in separate populations. The M201V variant of CYSLTR2 exhibits decreased responsiveness to LTD4, suggesting that this hypo-responsiveness underlies its asthma transmission-protecting effect.
# Give a concise answer in a few words to the question. You can help yourself by using the above informations.
# Question : What is the effect of the M201V variant of CYSLTR2 on responsiveness to LTD4?
# Relevant informations :
# 1.  Polymorphism in the CYSLTR2 gene has been associated with the inheritance of asthma in separate populations. The M201V variant of CYSLTR2 exhibits decreased responsiveness to LTD4, suggesting that this hypo-responsiveness underlies its asthma transmission-protecting effect.
# 2.  Cysteinyl leukotriene receptor 2 (CYSLTR2) is a receptor that binds to cysteinyl leukotrienes (CysLTs) and contributes to mediating allergic and hypersensitivity reactions in humans. It is expressed in various cell types, including blood eosinophils, platelets, and tissue mast cells.
# Give a concise answer in a few words to the question. You can help yourself by using the above informations.
# Question : What is the effect of the M201V variant of CYSLTR2 on responsiveness to LTD4?
# Relevant informations :
# 1.  Polymorphism in the CYSLTR2 gene has been associated with the inheritance of asthma in separate populations. The M201V variant of CYSLTR2 exhibits decreased responsiveness to LTD4, suggesting that this hypo-responsiveness underlies its asthma transmission-protecting effect.
# 2.  Cysteinyl leukotriene receptor 2 (CYSLTR2) is a receptor that binds to cysteinyl leukotrienes (CysLTs) and contributes to mediating allergic and hypersensitivity reactions in humans. It is expressed in various cell types, including blood eosinophils, platelets, and tissue mast cells.
# 3.  The human CYSLTR2 gene maps to chromosome 13 and consists of four exons. The protein encoded by CYSLTR2 is composed of 347 amino acids and shares only 31% amino acid identity with the CysLTR1 protein. CYSLTR2 is a G protein-coupled receptor that activates the Gq alpha subunit and/or Ga subunit of its coupled G protein when bound to its CysLT ligands.
# Give a concise answer in a few words to the question. You can help yourself by using the above informations.
# Question : What is the effect of the M201V variant of CYSLTR2 on responsiveness to LTD4?
# Relevant informations :
# 1.  Polymorphism in the CYSLTR2 gene has been associated with the inheritance of asthma in separate populations. The M201V variant of CYSLTR2 exhibits decreased responsiveness to LTD4, suggesting that this hypo-responsiveness underlies its asthma transmission-protecting effect.
# 2.  Cysteinyl leukotriene receptor 2 (CYSLTR2) is a receptor that binds to cysteinyl leukotrienes (CysLTs) and contributes to mediating allergic and hypersensitivity reactions in humans. It is expressed in various cell types, including blood eosinophils, platelets, and tissue mast cells.
# 3.  The human CYSLTR2 gene maps to chromosome 13 and consists of four exons. The protein encoded by CYSLTR2 is composed of 347 amino acids and shares only 31% amino acid identity with the CysLTR1 protein. CYSLTR2 is a G protein-coupled receptor that activates the Gq alpha subunit and/or Ga subunit of its coupled G protein when bound to its CysLT ligands.
# 4.  There are no selective inhibitors of CYSLTR2 in clinical use. However, Gemilukast has been reported to inhibit both CysLTR1 and CysLTR2. The role of CYSLTR2 in allergic and hypersensitivity diseases of humans must await the development of selective CysLTR2 inhibitors. Chronic treatment with Montelukast, Zafirlukast, and Pranlukast, drugs that are selective receptor antagonists of CysLTR1, reduces allergic and hypersensitivity responses in humans and animal models.
# Give a concise answer in a few words to the question. You can help yourself by using the above informations.

# %%
def process_batch_prompts(batch_prompts, tokenizer, model, device):
    inputs = [
        tokenizer.apply_chat_template(
            [{'role': 'system', 'content': 'You are a helpful assistant.'},
             {'role': 'user', 'content': prompt}], 
            tokenize=False,
            add_generation_prompt=True
        )
        for prompt in batch_prompts
    ]
    
    # Convertir les entrées en tenseurs pour le modèle
    inputs = tokenizer(inputs, return_tensors="pt", padding=True).to(device)
    
    # Générer les réponses pour le batch
    outputs = model.generate(
        input_ids=inputs['input_ids'],
        attention_mask=inputs['attention_mask'],
        max_new_tokens=32
    )
    
    # Décoder les réponses
    responses = [
        tokenizer.decode(output[inputs.input_ids.size(1):], skip_special_tokens=True)
        for output in outputs
    ]

    print(responses)
    
    return responses

# %%
import itertools

def chunked_iterable(iterable, size):
    it = iter(iterable)
    while True:
        chunk = tuple(itertools.islice(it, size))
        if not chunk:
            return
        yield chunk

# %%
# import time

# # TODO
# # Envoyez les prompts au modèle

# # k_values = [1, 2, 3, 4]
# k_values = [3]
# generated_responses = {}

# for k in k_values:
#     batch_size = 8
#     batch_responses = []

#     for i in range(0, len(prompts_k[k]), batch_size):
#         batch_prompts = prompts_k[k][i:i + batch_size]
        
#         # print(f"[k={k} | Batch {i}] Started generation...")
#         start_time = time.time()
        
#         batch_responses.extend(process_batch_prompts(batch, gen_tokenizer, gen_model, DEVICE))
        
#         end_time = time.time()
#         elapsed_time = end_time - start_time
        
#         print(f"[k={k} | Batch] Time for generation = {elapsed_time:.2f} seconds")

#     generated_responses[k] = batch_responses

#     print(f"Done with k = {k}!")

# # END TODO
# Out:
# ('Question : What is the effect of the M201V variant of CYSLTR2 on responsiveness to LTD4?\nRelevant informations :\n1.  Polymorphism in the CYSLTR2 gene has been associated with the inheritance of asthma in separate populations. The M201V variant of CYSLTR2 exhibits decreased responsiveness to LTD4, suggesting that this hypo-responsiveness underlies its asthma transmission-protecting effect.\n2.  Cysteinyl leukotriene receptor 2 (CYSLTR2) is a receptor that binds to cysteinyl leukotrienes (CysLTs) and contributes to mediating allergic and hypersensitivity reactions in humans. It is expressed in various cell types, including blood eosinophils, platelets, and tissue mast cells.\n3.  The human CYSLTR2 gene maps to chromosome 13 and consists of four exons. The protein encoded by CYSLTR2 is composed of 347 amino acids and shares only 31% amino acid identity with the CysLTR1 protein. CYSLTR2 is a G protein-coupled receptor that activates the Gq alpha subunit and/or Ga subunit of its coupled G protein when bound to its CysLT ligands.\nGive a concise answer in a few words to the question. You can help yourself by using the above informations.', 'Question : What is the key difference in the structure of carbapenems compared to penicillins?\nRelevant informations :\n1.   Carbapenems are structurally similar to penicillins, but with a carbon atom replacing the sulfur atom in position 1. They are biosynthesized through a series of steps involving the condensation of malonyl-CoA with glutamate-5-semialdehyde, followed by the formation of the β-lactam and saturated carbapenam core.\n2.   Carbapenems are a class of highly effective antibiotic agents commonly used for the treatment of severe or high-risk bacterial infections. They are usually reserved for known or suspected multidrug-resistant (MDR) bacterial infections and have a broader spectrum of activity compared to most cephalosporins and penicillins.\n3.   The growing prevalence of carbapenem-resistant Enterobacteriaceae has led to a renaissance of the use of antibiotics such as colistin. Pseudomonas aeruginosa and Acinetobacter baumannii are also resistant to carbapenems due to their expression of a wide range of resistance mechanisms, including beta lactamases and efflux pumps.\nGive a concise answer in a few words to the question. You can help yourself by using the above informations.', 'Question : What type of facets are there in the 8-demicubic honeycomb?\nRelevant informations :\n1.   The 8-demicubic honeycomb is a uniform space-filling tessellation in Euclidean 8-space, constructed as an alternation of the regular 8-cubic honeycomb. It is composed of two types of facets: 8-demicubes and 8-orthoplex facets.\n2.   The 8-demicubic honeycomb has three uniform construction symmetries, each represented by arrangements of different colors on the 256 8-demicube facets around each vertex. Its Voronoi tessellation is a quadrirectified 8-cubic honeycomb, containing all trirectified 8-orthoplex Voronoi cells.\n3.   The 6-demicubic honeycomb is a uniform space-filling tessellation in Euclidean 6-space, constructed as an alternation of the regular 6-cube honeycomb. It consists of two types of facets: 6-demicubes and 6-orthoplex facets.\nGive a concise answer in a few words to the question. You can help yourself by using the above informations.', 'Question : What is the legal status of 5F-AMB in the United States?\nRelevant informations :\n1.   5F-AMB is a controlled substance in several countries, including the United States, Germany, Sweden, Louisiana, Singapore, Japan, and China. The UNODC has recommended scheduling it as a Schedule II controlled research chemical.\n2.   5F-AMB, also known as 5F-MMB-PINACA, is an indazole-based synthetic cannabinoid used in synthetic cannabis products. It was first identified in Japan in 2014.\n3.   5-MeO-AMT is illegal in several countries, including Australia, Sweden, and the UK, while in the US, it is not scheduled at the federal level, but is illegal i ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 23
#      20 # print(f"[k={k} | Batch {i}] Started generation...")
#      21 start_time = time.time()
# ---> 23 batch_responses.extend(process_batch_prompts(batch, gen_tokenizer, gen_model, DEVICE))
#      25 end_time = time.time()
#      26 elapsed_time = end_time - start_time
#
# Cell In[25], line 16, in process_batch_prompts(batch_prompts, tokenizer, model, device)
#      13 inputs = tokenizer(inputs, return_tensors="pt", padding=True).to(device)
#      15 # Générer les réponses pour le batch
# ---> 16 outputs = model.generate(
#      17     input_ids=inputs['input_ids'],
#      18     attention_mask=inputs['attention_mask'],
#      19     max_new_tokens=32
#      20 )
#      22 # Décoder les réponses
#      23 responses = [
#      24     tokenizer.decode(output[inputs.input_ids.size(1):], skip_special_tokens=True)
#      25     for output in outputs
#      26 ]
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\transformers\generation\utils.py:2047, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2039     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2040         input_ids=input_ids,
#    2041         expand_size=generation_config.num_return_sequences,
#    2042         is_encoder_decoder=self.config.is_encoder_decoder,
#    2043         **model_kwargs,
#    2044     )
#    2046     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2047     result = self._sample(
#    2048         input_ids,
#    2049         logits_processor=prepared_logits_processor,
#    2050         stopping_criteria=prepared_stopping_criteria,
#    2051         generation_config=generation_config,
#    2052         synced_gpus=synced_gpus,
#    2053         streamer=streamer,
#    2054         **model_kwargs,
#    2055     )
#    2057 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2058     # 11. prepare beam search scorer
#    2059     beam_scorer = BeamSearchScorer(
#    2060         batch_size=batch_size,
#    2061         num_beams=generation_config.num_beams,
#    (...)
#    2066         max_length=generation_config.max_length,
#    2067     )
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\transformers\generation\utils.py:3007, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3004 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3006 # forward pass to get next token
# -> 3007 outputs = self(**model_inputs, return_dict=True)
#    3009 if synced_gpus and this_peer_finished:
#    3010     continue  # don't waste resources running the code we don't need
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\.cache\huggingface\modules\transformers_modules\microsoft\Phi-3-mini-128k-instruct\a90b62ae09941edff87a90ced39ba5807e6b2ade\modeling_phi3.py:1243, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1240 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1242 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1243 outputs = self.model(
#    1244     input_ids=input_ids,
#    1245     attention_mask=attention_mask,
#    1246     position_ids=position_ids,
#    1247     past_key_values=past_key_values,
#    1248     inputs_embeds=inputs_embeds,
#    1249     use_cache=use_cache,
#    1250     output_attentions=output_attentions,
#    1251     output_hidden_states=output_hidden_states,
#    1252     return_dict=return_dict,
#    1253 )
#    1255 hidden_states = outputs[0]
#    1256 logits = self.lm_head(hidden_states)
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\.cache\huggingface\modules\transformers_modules\microsoft\Phi-3-mini-128k-instruct\a90b62ae09941edff87a90ced39ba5807e6b2ade\modeling_phi3.py:1121, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1111     layer_outputs = self._gradient_checkpointing_func(
#    1112         decoder_layer.__call__,
#    1113         hidden_states,
#    (...)
#    1118         use_cache,
#    1119     )
#    1120 else:
# -> 1121     layer_outputs = decoder_layer(
#    1122         hidden_states,
#    1123         attention_mask=attention_mask,
#    1124         position_ids=position_ids,
#    1125         past_key_value=past_key_values,
#    1126         output_attentions=output_attentions,
#    1127         use_cache=use_cache,
#    1128     )
#    1130 hidden_states = layer_outputs[0]
#    1132 if use_cache:
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\.cache\huggingface\modules\transformers_modules\microsoft\Phi-3-mini-128k-instruct\a90b62ae09941edff87a90ced39ba5807e6b2ade\modeling_phi3.py:842, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     839 hidden_states = self.input_layernorm(hidden_states)
#     841 # Self Attention
# --> 842 attn_outputs, self_attn_weights, present_key_value = self.self_attn(
#     843     hidden_states=hidden_states,
#     844     attention_mask=attention_mask,
#     845     position_ids=position_ids,
#     846     past_key_value=past_key_value,
#     847     output_attentions=output_attentions,
#     848     use_cache=use_cache,
#     849 )
#     851 hidden_states = residual + self.resid_attn_dropout(attn_outputs)
#     853 residual = hidden_states
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\.cache\huggingface\modules\transformers_modules\microsoft\Phi-3-mini-128k-instruct\a90b62ae09941edff87a90ced39ba5807e6b2ade\modeling_phi3.py:334, in Phi3Attention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     328         raise ValueError(
#     329             f"The cache structure has changed since version v4.36. If you are using {self.__class__.__name__} "
#     330             "for auto-regressive decoding with k/v caching, please make sure to initialize the attention class "
#     331             "with a layer index."
#     332         )
#     333     kv_seq_len += past_key_value.get_usable_length(kv_seq_len, self.layer_idx)
# --> 334 cos, sin = self.rotary_emb(value_states, position_ids, seq_len=kv_seq_len)
#     336 query_states, key_states = apply_rotary_pos_emb(query_states, key_states, cos, sin, position_ids)
#     338 if past_key_value is not None:
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\mathi\anaconda3\envs\ml_env\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\.cache\huggingface\modules\transformers_modules\microsoft\Phi-3-mini-128k-instruct\a90b62ae09941edff87a90ced39ba5807e6b2ade\modeling_phi3.py:156, in Phi3LongRoPEScaledRotaryEmbedding.forward(self, x, position_ids, seq_len)
#     154     ext_factors = torch.tensor(self.long_factor, dtype=torch.float32, device=x.device)
#     155 else:
# --> 156     ext_factors = torch.tensor(self.short_factor, dtype=torch.float32, device=x.device)
#     158 inv_freq_shape = torch.arange(0, self.dim, 2, dtype=torch.int64, device=x.device).float() / self.dim
#     159 self.inv_freq = 1.0 / (ext_factors * self.base**inv_freq_shape)
#
# KeyboardInterrupt:

# %%
# TODO
import time
# Envoyez les prompts au modèle

# k_values = [1, 2, 3, 4]
k_values = [4]
generated_responses = {}

for k in k_values:
    batch_size = 4
    batch_responses = []

    # Utilisation de chunked_iterable pour créer des lots
    for batch_index, batch_prompts in enumerate(chunked_iterable(prompts_k[k], batch_size)):
        print(f"[k={k} | Batch {batch_index}] Started generation...")
        start_time = time.time()
        
        # Processus de traitement du lot
        batch_responses.extend(process_batch_prompts(batch_prompts, gen_tokenizer, gen_model, DEVICE))
        
        end_time = time.time()
        elapsed_time = end_time - start_time
        
        print(f"[k={k} | Batch {batch_index}] Time for generation = {elapsed_time:.2f} seconds")

    generated_responses[k] = batch_responses

    print(f"Done with k = {k}!")

# END TODO
# Out:
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# You are not running the flash-attention implementation, expect numerical differences.
# [k=4 | Batch 0] Started generation...
# ['Decreased responsiveness to LTD4', 'Carbapenems have a carbon atom in position 1 instead of a sulfur atom in penicillins.', 'Two types of facets: 8-demicubes and 80-orthoplex facets.', 'Scheduled as a Schedule II controlled substance in the United States.']
# [k=4 | Batch 0] Time for generation = 4.91 seconds
# [k=4 | Batch 1] Started generation...
# ['Androstenedione', 'μ-opioid receptor, κ-opioid receptor, and sigma σ1 receptor', 'Chromosome 7', 'Synthetic cannabinoid']
# [k=4 | Batch 1] Time for generation = 4.28 seconds
# [k=4 | Batch 2] Started generation...
# ['3-MeO-PCP', 'Non-coordinating anion', 'Proportional to temperature and Fermi level density of states.', 'Presenting antigens to T-cells for immune response activation.']
# [k=4 | Batch 2] Time for generation = 2.89 seconds
# [k=4 | Batch 3] Started generation...
# ['Doping silicon with antimony', 'Base absorbs HCl, enhancing reaction efficiency.', 'Dry chlorine treatment', 'Persistence length']
# [k=4 | Batch 3] Time for generation = 2.15 seconds
# [k=4 | Batch 4] Started generation...
# ['DMTMM is used for activating carboxylic acids for amide synthesis.', 'A permutation is a Baxter permutation if it avoids certain vincular patterns.', 'Approximately 3.2 million light-years.', 'Nourishment, sensory function, and defense against infection.']
# [k=4 | Batch 4] Time for generation = 3.45 seconds
# [k=4 | Batch 5] Started generation...
# ['The molecular mass of the TMEM267 protein is 24.2 kDa.', '"Being" or "origin"', '324 amino acids long', 'Ratio of speed of light in vacuum to phase velocity of light in medium']
# [k=4 | Batch 5] Time for generation = 3.66 seconds
# [k=4 | Batch 6] Started generation...
# ['Study of organism development from fertilization to adulthood', 'Exploiting symmetries in the integrand', 'Phosphatidylinositol 4-phosphate (PI4P)', 'To provide a comprehensive reference library for metabolite profiling experiments and facilitate the discovery of novel biomarkers.']
# [k=4 | Batch 6] Time for generation = 4.27 seconds
# [k=4 | Batch 7] Started generation...
# ['Degree of a Frankl-Rödl graph is equal to the number of coordinates in the hypercube.', 'SIGCHLD signal to the parent process', 'Aortic regurgitation, left ventricular hypertrophy, bundle branch blocks, abnormal displacement of the ostium in the right coron', 'Trans-defensins and cis-defensins']
# [k=4 | Batch 7] Time for generation = 4.86 seconds
# [k=4 | Batch 8] Started generation...
# ['Holweck pump', 'Human Nav1.7 channel', '20-53 stars per year', 'Hexose monosaccharides with six carbon atoms are called hexoses.']
# [k=4 | Batch 8] Time for generation = 3.20 seconds
# [k=4 | Batch 9] Started generation...
# ['DTT is used to reduce disulfide bonds in red blood cells and denature antigens in blood group systems.', 'Exhalation and urination', '48', '0°C']
# [k=4 | Batch 9] Time for generation = 4.38 seconds
# [k=4 | Batch 10] Started generation...
# ['The predicted molecular weight of the PROSER1 protein is 95.7 kdal.', 'PIP5K regulates neuronal morphology, suppresses axon branching, and promotes Wnt signaling for myelination.', 'Haplogroup M30 in India, the Middle East, and East Asia.', 'Miniaturization through nanotechnology']
# [k=4 | Batch 10] Time for generation = 4.74 seconds
# [k=4 | Batch 11] Started generation...
# ['Lightning UK', 'Inhibits IL-4 and IL-13 receptor assembly', 'Determines the "density" of units in a number field.', 'FP receptor agonists lower intraocular pressure in glaucoma treatment.']
# [k=4 | Batch 11] Time for generation = 3.53 seconds
# [k=4 | Batch 12] Started generation...
# ['Stepping Motor autofocus technology', "AMD's embedded APUs, including the G-Series, LX-Family, and R-Series.", 'Difference equations', 'Haloform formation from a methyl ketone in the presence of a base.']
# [k=4 | Batch 12] Time for generation = 4.19 seconds
# [k=4 | Batch 13] Started generation...
# ['Water of crystallization', 'Vegetation emissions', 'To diagnose blood and marrow disorders.', 'Itchy scalp and flakiness']
# [k=4 | Batch 13] Time for generation = 2.12 seconds
# [k=4 | Batch 14] Started generation...
# ['South Africa', 'Molecular hydrogen', 'Torsion spring', 'A tetraquark is a four-quark exotic meson.']
# [k=4 | Batch 14] Time for generation = 2.97 seconds
# [k=4 | Batch 15] Started generation...
# ['Invariant mass is the rest mass of a system, conserved in all reference frames.', 'Eosinophil peroxidase catalyzes the formation of hypohalous acids to kill bacteria.', 'Preimplantation genetic diagnosis (PGD)', 'Suppressing ionization with a thick semiconductor shell']
# [k=4 | Batch 15] Time for generation = 4.75 seconds
# [k=4 | Batch 16] Started generation...
# ['2-20x10^9/L', "Solving Laplace's equation and Helmholtz equation.", 'Seven-dimensional', 'Combination vaccines']
# [k=4 | Batch 16] Time for generation = 3.06 seconds
# [k=4 | Batch 17] Started generation...
# ['CFU-E stage', 'Involved in flagella assembly and motility', '1983', 'Mobile Station (MS)']
# [k=4 | Batch 17] Time for generation = 2.17 seconds
# [k=4 | Batch 18] Started generation...
# ['Electrons generated by photolysis of water in oxygenic photoautotrophic organisms.', 'Morning types have their peak body temperature in the morning.', 'Azithromycin', 'Anthranilate synthase catalyzes the conversion of chorismate to anthranilate, an intermediate in the biosynthesis of try']
# [k=4 | Batch 18] Time for generation = 5.14 seconds
# [k=4 | Batch 19] Started generation...
# ['Block natural light for photosynthetic organisms.', 'Palindromic numbers', 'Lupus', '3β-Androstanediol']
# [k=4 | Batch 19] Time for generation = 2.53 seconds
# [k=4 | Batch 20] Started generation...
# ['A function that assigns an element to each set in a collection.', 'ALC-0315 is a synthetic lipid with a terti0ary amine structure, used in the BNT162', 'Poor soil conservation, unstable farming methods, and overgrazing', 'Specific latent heat']
# [k=4 | Batch 20] Time for generation = 4.94 seconds
# [k=4 | Batch 21] Started generation...
# ['Synthesis method and equipment cost', 'β-barrel structure with anti-parallel β-strands and α-helices', 'IEEE 754-1985 standard', 'Avidemux is a free and open-source video editing software that can perform non-linear video editing functions.']
# [k=4 | Batch 21] Time for generation = 4.23 seconds
# [k=4 | Batch 22] Started generation...
# ['White crownbeard, yellow ironweed, and Helianthemum canadense', 'Five minutes', 'Noncovalent intermolecular interactions', 'Chitinophagaceae is a family of aerobic or facultatively anaerobic, rod-shaped bacteria in the']
# [k=4 | Batch 22] Time for generation = 5.20 seconds
# [k=4 | Batch 23] Started generation...
# ['110 format', 'Phyllosilicates', 'Telescoping hiking poles', 'Membrane-bound oxaloacetate decarboxylases catalyze the decarboxylation of oxaloacetate to py']
# [k=4 | Batch 23] Time for generation = 5.14 seconds
# [k=4 | Batch 24] Started generation...
# ['Sodium amalgam is a mercury-sodium alloy used as a reducing agent in organic chemistry and in high-press', 'To determine if a loop is parallelizable by checking for dependencies between loop statements.', 'Transponder used in air traffic control is for identifying aircraft and maintaining separation between planes.', 'Phosphorylated tyrosine residues']
# [k=4 | Batch 24] Time for generation = 5.06 seconds
# [k=4 | Batch 25] Started generation...
# ['Adduction, extension, and internal rotation of the shoulder', 'Inefficient bit usage', 'Defined by ISO/IEC standards and ITU-T Recommendation T.802.', 'Two encryption operations and one encryption on associated data for each message block.']
# [k=4 | Batch 25] Time for generation = 3.96 seconds
# [k=4 | Batch 26] Started generation...
# ['Ibritumomab tiuxetan is a monoclonal antibody radioimmunotherapy that targets CD20 on B cells,', 'Axonometry is used in engineering, architecture, art, CAD systems, and visual computing tools.', "Measures system's predictability and chaos", 'Suffix array and LCP array']
# [k=4 | Batch 26] Time for generation = 5.14 seconds
# [k=4 | Batch 27] Started generation...
# ['Trigonal prismatic geometry', 'CLEC5A induces TNF-α, IL-1, IL-6, IL-8, IL-17A, MIP', 'Originated in South America during the Eocene, likely from Africa.', "To specify a precise location on Earth's surface."]
# [k=4 | Batch 27] Time for generation = 5.35 seconds
# [k=4 | Batch 28] Started generation...
# ['DMQ hydroxylase enzyme in ubiquinone biosynthesis', '226°C', 'Derived from the amino acid phenylalanine and found in chocolate, buckwheat, and flowers.', 'Chemical vapor deposition in semiconductor production.']
# [k=4 | Batch 28] Time for generation = 4.89 seconds
# [k=4 | Batch 29] Started generation...
# ['Testis', 'Regulates cellular processes, including protein O-glycosylation, ciliogenesis, and PCNA degradation.', '"Wrong" or "twisted"', 'Juan Benet']
# [k=4 | Batch 29] Time for generation = 4.84 seconds
# [k=4 | Batch 30] Started generation...
# ['Treating NaBAr′4 with hydrogen chloride in diethyl ether.', 'Laser technology', 'Pfizer', 'Lightface analytic sets']
# [k=4 | Batch 30] Time for generation = 3.55 seconds
# [k=4 | Batch 31] Started generation...
# ['Clostridiaceae', 'Agaric acid inhibits sweat gland activity', 'G-type main-sequence star', 'Pleurotolysin B belongs to the MACPF superfamily.']
# [k=4 | Batch 31] Time for generation = 2.82 seconds
# [k=4 | Batch 32] Started generation...
# ['Human Papilloma Virus (HPV) infection', 'Via Licensing Corporation', 'Debye screening', '13 years']
# [k=4 | Batch 32] Time for generation = 2.37 seconds
# [k=4 | Batch 33] Started generation...
# ['Increased risk of cancer, particularly skin tumors.', '16.5-33 x 5.5-8.8 μm', 'DECtapes, fixed-head disks, and cartridge disk drives', 'GPR99']
# [k=4 | Batch 33] Time for generation = 3.55 seconds
# [k=4 | Batch 34] Started generation...
# ['High heat transfer coefficients, smaller condenser size, and cost-effectiveness.', 'Plane section', 'Eliminate leprosy by 2025', 'Kinetic energy of a linear rigid rotor is given by the expression (1/2)Iω², where I is the moment of inertia']
# [k=4 | Batch 34] Time for generation = 5.01 seconds
# [k=4 | Batch 35] Started generation...
# ['Protonation', 'Ion transporter (IT) superfamily', 'APC, AAAP, DAACS, LIVCS, HAAAP, LIV-E, NAAT, ArcD, PAAP families', 'Irregular variable stars in our own galaxy']
# [k=4 | Batch 35] Time for generation = 5.02 seconds
# [k=4 | Batch 36] Started generation...
# ['Small heat shock protein 27 (HSP27)', 'DNA barcode for animal species identification', 'Cardiac neural crest cells contribute to the formation of connective tissues in the aortic arch arteries and the smooth muscle of great ar', 'Modified (M)']
# [k=4 | Batch 36] Time for generation = 5.25 seconds
# [k=4 | Batch 37] Started generation...
# ['RSVP reserves network resources for application data streams.', 'L-655,708 acts as an inverse agonist at the α5 subtype of the GABAA receptor.', 'Trusted types and SameSite cookie parameter', 'Insecticide and myasthenia gravis treatment']
# [k=4 | Batch 37] Time for generation = 4.85 seconds
# [k=4 | Batch 38] Started generation...
# ['Trigonal bipyramidal', 'Present peptides to CD8+ T-cells for immune response.', 'TMEM81 gene is located on chromosomal band 1q32.1 in humans.', 'Regulating physiological color change in fish.']
# [k=4 | Batch 38] Time for generation = 4.29 seconds
# [k=4 | Batch 39] Started generation...
# ['Predictable structures stabilized by noncovalent interactions', 'Pyridoxal phosphate', 'Degradation of misfolded, damaged, and regulatory proteins; antigen presentation.', 'Corrects for thermal expansion of liquids.']
# [k=4 | Batch 39] Time for generation = 3.87 seconds
# [k=4 | Batch 40] Started generation...
# ['Improves exercise performance and recovery, enhances blood flow, and combats oxidative stress.', 'Hexeract', 'Vomitoxin decreases brain uptake of tryptophan, leading to reduced serotonin synthesis and anorexic effects.', 'To provide non-invasive ventilation and maintain lung volumes in newborns with IRDS.']
# [k=4 | Batch 40] Time for generation = 5.07 seconds
# [k=4 | Batch 41] Started generation...
# ['Hard-easy effect', 'Epoxygenase activity', 'Glycerone phosphate, NADH, H+', 'To stabilize drugs and inhibit transaminase reactions.']
# [k=4 | Batch 41] Time for generation = 2.95 seconds
# [k=4 | Batch 42] Started generation...
# ['Oospores', 'Two elements are equivalent if they are in the same orbit under a group action.', 'To ensure compatibility and prevent transfusion reactions.', 'Allows PGCs to reach the gonad and ensures the quality of PGCs by removing those with defects.']
# [k=4 | Batch 42] Time for generation = 4.66 seconds
# [k=4 | Batch 43] Started generation...
# ['Rapid rate of speech, erratic rhythm, poor syntax', 'Radiometry is the study of the distribution of radiant energy in space and time.', 'Microstrip antenna', 'Web server provides environment variables to CGI script.']
# [k=4 | Batch 43] Time for generation = 3.29 seconds
# [k=4 | Batch 44] Started generation...
# ['Hemichromes', 'B2-3 IV-V spectral types', 'GSK-3 inhibitor', 'Y chromosome, position chrY:11,907,522']
# [k=4 | Batch 44] Time for generation = 3.41 seconds
# [k=4 | Batch 45] Started generation...
# ['Spheroidal weathering', 'Epinephrine injection', 'L-threonine, L-aspartate, pyruvic acid, and L-methionine', 'Neurolytic block']
# [k=4 | Batch 45] Time for generation = 4.31 seconds
# [k=4 | Batch 46] Started generation...
# ['Gestational diabetes, high blood pressure, anemia, infection, ectopic pregnancy, miscarriage, placental ab', 'Didymella bryoniae', 'Snapdragon 8 Gen 1', 'Around 45°C']
# [k=4 | Batch 46] Time for generation = 4.95 seconds
# [k=4 | Batch 47] Started generation...
# ['Dimercaprol', 'ANNOVAR annotates and prioritizes genetic variants for rare diseases.', 'Doxycycline', 'To ensure quality management systems for customer satisfaction, continuous improvement, and process efficiency.']
# [k=4 | Batch 47] Time for generation = 2.97 seconds
# [k=4 | Batch 48] Started generation...
# ['To study dopamine transporter distribution and as a substitute for cocaine in animal studies.', 'MIT License', 'Harmine is a reversible inhibitor of monoamine oxidase A (MAO-A).', 'Diagnose and treat large intestine conditions, detect colorectal cancer, reduce mortality rates.']
# [k=4 | Batch 48] Time for generation = 4.03 seconds
# [k=4 | Batch 49] Started generation...
# ['Tetrathionate serves as a terminal electron acceptor for Salmonella enterica serotype Typhimurium, aiding in its growth', 'Cytochrome P450 reductase enzyme', 'Vascular rings causing extrinsic compression type of tracheomalacia.', '2√2']
# [k=4 | Batch 49] Time for generation = 5.00 seconds
# [k=4 | Batch 50] Started generation...
# ['Time-independent Hamiltonian evolution of state vectors', 'Jaccard index = Size of intersection / Size of union', 'Octahedral, D2h', 'Isolate production zones and allow selective perforation and production.']
# [k=4 | Batch 50] Time for generation = 2.64 seconds
# [k=4 | Batch 51] Started generation...
# ['Difference in surface tension between alcohol and water', 'Headache, seizures, and nausea', 'Client-server model', 'Sphingosine-1-Phosphate regulates cell growth, survival, motility, angiogenesis, and inflammatory']
# [k=4 | Batch 51] Time for generation = 4.98 seconds
# [k=4 | Batch 52] Started generation...
# ['The Hill sphere measures the gravitational sphere of influence of a smaller body in the presence of a more massive body.', 'Formoterol is a long-acting β2 agonist that relaxes airway smooth muscle, causing bronchodilation and relieving ast', 'Thiamine pyridinylase and Aminopyrimidine aminohydrolase', 'Distinct shell shapes, ribbing patterns, and presence or absence of a keel.']
# [k=4 | Batch 52] Time for generation = 4.81 seconds
# [k=4 | Batch 53] Started generation...
# ['Ca4Mg(AsO3OH)2(AsO4)2·11H2O', 'Up to 12 hours', 'Ba(ClO4)2', 'Reducing agents in hydroperoxide reduction and stabilizers in polymers']
# [k=4 | Batch 53] Time for generation = 3.90 seconds
# [k=4 | Batch 54] Started generation...
# ['TWDP fading explains both signal strengthening and weakening in radio communication systems.', 'Rhenium dioxide (ReO2)', 'Condensation polymerization', 'ImgBurn supports BIN, CUE, and ISO formats.']
# [k=4 | Batch 54] Time for generation = 3.28 seconds
# [k=4 | Batch 55] Started generation...
# ['20 terabytes to 2.1 exabytes', 'Dscam1 protein generates thousands of isoforms in Drosophila for self-avoidance.', 'Lead and boron-doped polyethylene plates', 'Loricrin']
# [k=4 | Batch 55] Time for generation = 3.93 seconds
# [k=4 | Batch 56] Started generation...
# ["The van 't Hoff factor measures the effect of a solute on colligative properties and the actual number of particles in solution after dissociation or association", '75%', 'Triggers inhalation reflex, increases breathing rate', 'Five minutes']
# [k=4 | Batch 56] Time for generation = 5.07 seconds
# [k=4 | Batch 57] Started generation...
# ['Interval arithmetic', 'Didymella bryoniae survives on deceased vines, crop debris, and seeds.', 'Thiamin diphosphate (TPP)', 'Weak field ligands favor tetrahedral geometry in four-coordinated nickel(II) complexes.']
# [k=4 | Batch 57] Time for generation = 4.35 seconds
# [k=4 | Batch 58] Started generation...
# ['Phonograph', 'Flare fittings require modification with a special tool.', '600 regular tetrahedra', 'Azanide']
# [k=4 | Batch 58] Time for generation = 2.38 seconds
# [k=4 | Batch 59] Started generation...
# ['Poor, with a 67% five-year survival rate for cancerous lung sarcomatoid carcinomas.', '8 unique runcinations of the runcinated 7-simplex.', 'Remnant cores of early protoplanets', 'Quadriradiate, triradiate, biradiate.']
# [k=4 | Batch 59] Time for generation = 4.45 seconds
# [k=4 | Batch 60] Started generation...
# ['Dimercaprol', "VESA's Display Data Channel (DDC) standard", 'Hydrothermal vent, deep-sea', '.heif']
# [k=4 | Batch 60] Time for generation = 2.61 seconds
# [k=4 | Batch 61] Started generation...
# ['Molecular analysis using 18S rRNA, ITS, and ribulose-bisphosphate carboxylase genes', '8 to 12 GHz', '"th", "en", "he", "in", "er"', "Newton's third law of motion"]
# [k=4 | Batch 61] Time for generation = 5.07 seconds
# [k=4 | Batch 62] Started generation...
# ['Phosphorylase kinase activates glycogen phosphorylase, stimulating glycogen breakdown.', 'Ulbrich distribution', 'Ubiquitination', 'A number must be 4 more than a multiple of 5.']
# [k=4 | Batch 62] Time for generation = 4.63 seconds
# [k=4 | Batch 63] Started generation...
# ['Helium, neon, argon, and nitrogen', 'Tzanck test used to diagnose herpes simplex, varicella, pemphigus, leishmaniasis, and lepros', '1.8% psilocybin', 'D-branes']
# [k=4 | Batch 63] Time for generation = 4.82 seconds
# [k=4 | Batch 64] Started generation...
# ['Generally stable in childhood, fatal in neonatal form.', 'Eudoxus of Cnidus', 'Positive-sense single-stranded RNA genome', 'Based on the 7-demicube']
# [k=4 | Batch 64] Time for generation = 2.78 seconds
# [k=4 | Batch 65] Started generation...
# ['Differential cryptanalysis', 'Colourless', 'p-Toluenesulfonyl chloride is used for converting alcohols into toluenesulfonate esters and amines', 'Glycerol dehydrogenase is a metal-dependent alcohol dehydrogenase enzyme.']
# [k=4 | Batch 65] Time for generation = 5.01 seconds
# [k=4 | Batch 66] Started generation...
# ['B6 Coxeter plane', 'Molybdopterin is a cofactor essential for the function of molybdenum-containing enzymes involved in redox re', 'Insulation against erosion', 'Bioceramic material']
# [k=4 | Batch 66] Time for generation = 4.87 seconds
# [k=4 | Batch 67] Started generation...
# ['Truncated octacross, bitruncated octacross, tritruncated octacross', 'Silicone prostheses, custom or mass-produced.', 'Cable modems support functionality at multiple layers of the OSI model, including the physical, data link, network, transport, and application layers.', 'Smooth induction and rapid emergence from anesthesia']
# [k=4 | Batch 67] Time for generation = 4.94 seconds
# [k=4 | Batch 68] Started generation...
# ['Ca3(AsO4)2', 'Dimeric enzyme with three conserved domains and a mobile lid active site', 'Deprotonation of carboxylic acids with bases like sodium hydroxide or sodium bicarbonate.', 'ITIM inhibits phagocytosis upon CD33 binding sialic acids.']
# [k=4 | Batch 68] Time for generation = 4.68 seconds
# [k=4 | Batch 69] Started generation...
# ['Avoidance of triggers and medication like sodium valproate.', 'Active galactic nucleus with a relativistic jet and high brightness due to beaming', '445 units sold', 'R-469A is a substitute for R-23 in test chambers for climate simulation.']
# [k=4 | Batch 69] Time for generation = 3.89 seconds
# [k=4 | Batch 70] Started generation...
# ['Thyroxine 5-deiodinase inactivates thyroid hormones by deiodination.', 'Involuntary bodily reactions, such as ideomotor phenomenon', 'Cytochrome P450 epoxygenases', 'Gram-negative, heterotrophic, psychrophilic or mesophilic, aerobic bacteria genus from the family of Flav']
# [k=4 | Batch 70] Time for generation = 4.93 seconds
# [k=4 | Batch 71] Started generation...
# ['Glucose inhibits orexin cells via tandem pore potassium channels.', 'Copper(II) sulfate', 'H4P2O7', 'PLRU algorithm']
# [k=4 | Batch 71] Time for generation = 3.62 seconds
# [k=4 | Batch 72] Started generation...
# ['Budding mechanism', 'HD 89345 b has a mass of 35.7 Earths.', '155.52 Mbit/s', 'Felinine']
# [k=4 | Batch 72] Time for generation = 3.51 seconds
# [k=4 | Batch 73] Started generation...
# ['HIV-induced myocarditis', 'Equivalence, specialization, redundancy, complementarity, transfer, concurrency', 'Primers provide a starting point for DNA polymerase to synthesize a complementary DNA strand.', 'International Code of Phylogenetic Nomenclature (PhyloCode)']
# [k=4 | Batch 73] Time for generation = 3.83 seconds
# [k=4 | Batch 74] Started generation...
# ['To protect carbonyl groups during selective reduction reactions.', 'Pyridoxal phosphate', 'Dispanin proteins inhibit cell invasion by harmful viruses through S-palmitoylation.', "Brain's resting state network"]
# [k=4 | Batch 74] Time for generation = 4.02 seconds
# [k=4 | Batch 75] Started generation...
# ['PtdIns(3,4)P2 acts as a second messenger in cell signaling pathways, activating pathways that regulate cell', 'A 3-4 duoprism in 4-dimensional geometry.', 'LNTX-1 irreversibly antagonizes acetylcholine receptors, decreasing muscular and neuronal transmission, leading to imm', 'A local property in algebra is one that can be detected from a small neighborhood of an object.']
# [k=4 | Batch 75] Time for generation = 5.24 seconds
# [k=4 | Batch 76] Started generation...
# ['Light energy harvested by oxygenic photoautotrophic organisms', '2,3-DCPP is a precursor in the synthesis of aripiprazole, cariprazine, and brilarox', 'Pistol shrimp uses bioluminescence from a collapsing bubble to stun or kill prey.', 'Phycoerythrin captures light energy and transfers it to chlorophyll in photosynthesis.']
# [k=4 | Batch 76] Time for generation = 4.78 seconds
# [k=4 | Batch 77] Started generation...
# ['8 kHz', 'WNK1 regulates potassium secretion and blood pressure by modulating sodium chloride cotransporters and potassium channels', 'C286 activates the RARβ receptor.', '122 °C']
# [k=4 | Batch 77] Time for generation = 4.98 seconds
# [k=4 | Batch 78] Started generation...
# ['Maritime pine bark', 'Reacts with water and carbon dioxide in the air.', 'Enzyme activators', 'p110δ is essential for immune cell signaling and a promising drug target for modulating immune responses.']
# [k=4 | Batch 78] Time for generation = 4.25 seconds
# [k=4 | Batch 79] Started generation...
# ['NBP2 is involved in cytosolic iron-sulfur protein assembly and interacts with proteins involved in various cellular processes.', 'Basal sliding, glacial quakes, bed deformation, and internal deformation.', 'Measure of similarity between sample sets or binary classification performance', 'Head direction cells']
# [k=4 | Batch 79] Time for generation = 4.89 seconds
# [k=4 | Batch 80] Started generation...
# ['Hepatic lipase breaks down triacylglycerides in IDL, releasing free fatty acids and converting IDL to LDL', 'Cyclooctatetraene has alternating single and double C-C bonds, but is non-aromatic.', 'Glutathione synthetase in plants catalyzes the formation of glutathione, a key molecule in plant defense against stressors and', 'Approximately 67°C']
# [k=4 | Batch 80] Time for generation = 5.01 seconds
# [k=4 | Batch 81] Started generation...
# ['To prevent potential hazards by limiting liquid volume and ensuring a vacuum tight seal.', 'Sand, treated sand, ceramic materials', 'To ensure the safety and quality of food products.', 'Hydrogen fluoride']
# [k=4 | Batch 81] Time for generation = 3.73 seconds
# [k=4 | Batch 82] Started generation...
# ['The predicted molecular weight of the C6orf165 protein is 71.20 kDa.', 'Beta-galactosidase', 'ARM-based microcontrollers (i.MX, S32, Layerscape/QorIQ series) and Multicore', 'O(n^2.376)']
# [k=4 | Batch 82] Time for generation = 5.28 seconds
# [k=4 | Batch 83] Started generation...
# ['To restore normal knee function and prevent complications.', 'Rubbing, irritation, scratching, stress, anxiety, depression.', 'Four ocelli on each side of the head and 21 pairs of legs, with some exceptions.', 'Separating cells from their environment and regulating molecule flow']
# [k=4 | Batch 83] Time for generation = 3.91 seconds
# [k=4 | Batch 84] Started generation...
# ['Mycoplasma mycoides subsp. mycoides', 'Plasmid DNA', 'Prussian blue', 'Ascomycota phylum']
# [k=4 | Batch 84] Time for generation = 2.52 seconds
# [k=4 | Batch 85] Started generation...
# ['Involuntary muscle twitches, fatigue, numbness, muscle cramping', '80 bits', 'Cloud base height affects radiation transfer and global climate patterns.', 'The visual cortex in the occipital lobe processes visual information.']
# [k=4 | Batch 85] Time for generation = 3.89 seconds
# [k=4 | Batch 86] Started generation...
# ['Acariformes', 'Hydrogen peroxide, hydrazine, and solid rocket propellant compositions', 'APN identifies network connection and service for mobile devices to establish data connections.', 'Dennis Gabor']
# [k=4 | Batch 86] Time for generation = 3.55 seconds
# [k=4 | Batch 87] Started generation...
# ['Catalyzes acetoacetyl-CoA formation from acetyl-CoA', 'Converts 3-dehydroquinate to 3-dehydroshikimate and H2O', 'File operations, device operations, game controllers, sound routines', 'Dry and Wet systems']
# [k=4 | Batch 87] Time for generation = 4.39 seconds
# [k=4 | Batch 88] Started generation...
# ['Proportional ratio between model/drawing and original', 'Holweck pump design', 'Symmetrical transfer function matrix.', 'Trisetum species belong to the family Poaceae.']
# [k=4 | Batch 88] Time for generation = 2.50 seconds
# [k=4 | Batch 89] Started generation...
# ['Acetalization with ethylene glycol', 'To diagnose heart failure, monitor therapy, and assess hemodynamic status in critically ill patients.', 'To identify lichens by analyzing colour changes from chemical reactions.', 'Red to nearly black']
# [k=4 | Batch 89] Time for generation = 3.87 seconds
# [k=4 | Batch 90] Started generation...
# ['Deter herbivores, attract pollinators', 'Congenital/juvenile-onset myotonic muscular dystrophy type I', '7.3 km/s', 'Glycogen phosphorylase']
# [k=4 | Batch 90] Time for generation = 3.78 seconds
# [k=4 | Batch 91] Started generation...
# ['David Jablon', 'Recovered from spent pulping liquids or sulfite pulping process', 'Pythium insidiosum', 'Haplogroup M8 originated from haplogroup M in East Asia.']
# [k=4 | Batch 91] Time for generation = 3.17 seconds
# [k=4 | Batch 92] Started generation...
# ['Transport of organic di-/tricarboxylates, dicarboxylate amino acids, inorganic sulfate, and', 'Protein denaturation', 'Describes behavior of finite-state machines based on current state and inputs.', 'To delay stall and improve handling at high angles of attack.']
# [k=4 | Batch 92] Time for generation = 4.96 seconds
# [k=4 | Batch 93] Started generation...
# ['β1 Sagittarii and β2 Sagittarii', 'Principle of partition between stationary and mobile phase', '12.3-megapixel CMOS sensor', 'C19H38O']
# [k=4 | Batch 93] Time for generation = 3.12 seconds
# [k=4 | Batch 94] Started generation...
# ['At least 2048 bits', 'Dynorphin primarily binds to the κ-opioid receptor (KOR).', 'Merkle-Damgard construction with a one-way compression function.', 'Causes of opportunistic infections include immunodeficiency, malnutrition, genetic predisposition, skin damage, medical procedures']
# [k=4 | Batch 94] Time for generation = 5.20 seconds
# [k=4 | Batch 95] Started generation...
# ['+11.2', 'Inhibits transcription elongation', 'Production of isomaltooligosaccharide syrup', 'Decreased drug effectiveness with repeated use']
# [k=4 | Batch 95] Time for generation = 2.40 seconds
# [k=4 | Batch 96] Started generation...
# ['CMP in STI is used for planarizing shallow trenches and enhancing isolation between devices and active areas.', 'A tree and forest mutually recursive data types.', "20.7% of the object's mass", 'Sound argument']
# [k=4 | Batch 96] Time for generation = 4.38 seconds
# [k=4 | Batch 97] Started generation...
# ['Track PRF and broadcast noise on both sides of the skin reflection.', "Existential phenomenology focuses on human existence, lived experience, and the individual's freedom to shape their own world.", '{3,3,3k,1}', "Variation due to Earth's eccentric orbit and axial tilt."]
# [k=4 | Batch 97] Time for generation = 4.51 seconds
# [k=4 | Batch 98] Started generation...
# ['Calibrated submanifolds minimize volume within their homology class.', 'Geomorphing and LOD blending', 'Potential treatment for Treatment-Resistant Depression.', 'Adults over forty years old']
# [k=4 | Batch 98] Time for generation = 2.94 seconds
# [k=4 | Batch 99] Started generation...
# ['Military base microgrid', 'Chromosome 10, long arm', '10-60 base pairs long', 'C7 and D7']
# [k=4 | Batch 99] Time for generation = 2.15 seconds
# [k=4 | Batch 100] Started generation...
# ['8 to 16 rods', 'Cyclization of cis-N-methyl-3-thiocyanoacrylamide to form a white solid S(CH2', 'TOI-178 has the longest chain of Laplace resonances and unusual density variations among its planets.', 'Children between 6 months and 5 years old.']
# [k=4 | Batch 100] Time for generation = 5.10 seconds
# [k=4 | Batch 101] Started generation...
# ['3/4 inch wide', 'P-type nickel oxide', 'Approximately 12.2 billion years old', 'Distortions in sampling due to aliasing, aperture error, jitter, noise, and quantization.']
# [k=4 | Batch 101] Time for generation = 4.29 seconds
# [k=4 | Batch 102] Started generation...
# ['Bijuva is a combined estrogen and progestogen oral medication for menopausal symptoms.', 'SH2 domain', 'CPT II transfers long-chain fatty acids into mitochondria for energy production.', 'Describes behavior of finite-state machines based on current state and inputs.']
# [k=4 | Batch 102] Time for generation = 4.56 seconds
# [k=4 | Batch 103] Started generation...
# ['Angiogenesis', 'To maintain constant data rate and bit density as the read head moves away from the disc center.', 'C4 carbon fixation pathway', 'Anthranilate synthase catalyzes the first step in the biosynthesis of indole and tryptophan by converting chorismate']
# [k=4 | Batch 103] Time for generation = 5.25 seconds
# [k=4 | Batch 104] Started generation...
# ['Regeneron Pharmaceuticals', 'Autotaxin generates LPA by converting lysophosphatidylcholine into LPA through its lysophospholipase D activity', 'Conversion of Fe(II) to Fe(II,III) oxide with H2 release.', 'Andreotti-Norguet formula']
# [k=4 | Batch 104] Time for generation = 5.24 seconds
# [k=4 | Batch 105] Started generation...
# ['To provide a quick energy source for muscle contraction and regulate blood glucose levels.', 'Algebraic numbers', 'Cold air moving over warmer lake water.', 'Orthologous sequences in mammals, aves, reptiles, amphibians, and fishes.']
# [k=4 | Batch 105] Time for generation = 4.40 seconds
# [k=4 | Batch 106] Started generation...
# ['Nucleus, oocyte, testes, embryonic development', 'Alphaproteobacteria, Gammaproteobacteria, and Flavobacteriia', 'Converts D-glucose-1-phosphate to D-glucose-6-phosphate', 'Istaroxime inhibits Na+/K+ ATPase, increasing intracellular calcium for improved cardiac contraction.']
# [k=4 | Batch 106] Time for generation = 5.02 seconds
# [k=4 | Batch 107] Started generation...
# ['To observe ocean color, estimate chlorophyll and sediment concentrations, and monitor oceanic productivity and the global carbon cycle.', 'Pinosylvin synthase and trihydroxystilbene synthase', '24,000 to 41,600 g/mol', 'Lipstatin originates from linoleic acid, octanoic acid, and L-leucine through enzymatic biosynthesis.']
# [k=4 | Batch 107] Time for generation = 5.05 seconds
# [k=4 | Batch 108] Started generation...
# ['Coleco Adam operating system, EOS', 'Aquarius', 'Formation of the purine ring on ribose', 'Mediating leukocyte adhesion to endothelium']
# [k=4 | Batch 108] Time for generation = 3.08 seconds
# [k=4 | Batch 109] Started generation...
# ['Hepatic lipase breaks down triacylglycerides in IDL to LDL, regulating triglyceride levels in the blood.', 'Trypsinogen', '10-60 base pairs long', 'Chlorophyllase initiates chlorophyll breakdown to chlorophyllide and phytol, essential for plant development and survival.']
# [k=4 | Batch 109] Time for generation = 5.29 seconds
# [k=4 | Batch 110] Started generation...
# ['A CMTS primarily enables high-speed data services like cable Internet and VoIP to cable subscribers by connecting the headend to the Internet and facilit', 'Cervical dysplasia, cervical cancer, trauma, low estrogen levels, rape, "rough sex"', 'Chromosome 8, 636 bp long', 'Milligrams per liter (mg/L)']
# [k=4 | Batch 110] Time for generation = 5.36 seconds
# [k=4 | Batch 111] Started generation...
# ['Layered double hydroxide structure with brucite-like layers of iron(II) hydroxide.', 'Ether bond', '120 minutes for infusion, followed by a 22-hour continuous infusion of fluorouracil.', 'Haplogroup Q-M3 is most commonly found in Meso & South America.']
# [k=4 | Batch 111] Time for generation = 5.07 seconds
# [k=4 | Batch 112] Started generation...
# ['Rituximab', 'Graphite', "Gravitational interaction with other planets can distort a planet's orbit from a near-perfect circle to an eccentric shape.", "GTPCH catalyzes the conversion of GTP to 7,8-DHNP-3'-TP, a precursor for THB,"]
# [k=4 | Batch 112] Time for generation = 5.07 seconds
# [k=4 | Batch 113] Started generation...
# ['1GHz VIA C7-M processor', 'Innate immunity', 'Inhibits coagulation factors and platelet aggregation.', '4-hydroxybenzoate and pyruvate']
# [k=4 | Batch 113] Time for generation = 2.88 seconds
# [k=4 | Batch 114] Started generation...
# ['HLA-DQ1 associated with autoimmune diseases and chronic infections.', 'Facultative anaerobe', 'Zirconocene dichloride is a colourless diamagnetic metallocene solid.', 'RNA primers are removed and replaced with new deoxyribonucleotides.']
# [k=4 | Batch 114] Time for generation = 3.69 seconds
# [k=4 | Batch 115] Started generation...
# ['Originally developed as a treatment for diabetes.', 'CDW warms and melts ice shelves from below.', 'Limnephilidae', 'To achieve finer detail in printed halftone images.']
# [k=4 | Batch 115] Time for generation = 3.04 seconds
# [k=4 | Batch 116] Started generation...
# ['Computed axial tomography (CAT)', 'The option becomes null and void.', 'Maintain transparency and refractive index, prevent precipitation, and increase stress tolerance.', 'IgG antibodies primarily function in humoral immunity by binding to pathogens, activating the complement system, neutralizing toxins,']
# [k=4 | Batch 116] Time for generation = 5.11 seconds
# [k=4 | Batch 117] Started generation...
# ["Fermi's golden rule", 'Androstanediol', 'O(d) in the worst case for both sorted linked lists and arrays.', 'The half-life of 241Bk is 1,381,000 years.']
# [k=4 | Batch 117] Time for generation = 4.27 seconds
# [k=4 | Batch 118] Started generation...
# ['The inverse limit of an inverse system of discrete finite groups is isomorphic to a profinite group.', 'Non-destructive 3D imaging with nanometer-scale resolution for scientific and industrial applications.', 'Approximately 7.2 g/cm³', 'To improve write throughput, reduce recovery time, and allow for snapshots or time-travel features.']
# [k=4 | Batch 118] Time for generation = 3.80 seconds
# [k=4 | Batch 119] Started generation...
# ['Gamma motor neurons', 'Represent minimum s-t cuts in undirected graph with capacities.', 'Atrial fibrillation', 'pKa of nitroxyl is about 11.']
# [k=4 | Batch 119] Time for generation = 2.82 seconds
# [k=4 | Batch 120] Started generation...
# ['Inhibits H. pylori-derived urease', 'To restore normal knee function and prevent complications.', '+1.06 volts', 'Quadrature Amplitude Modulation (QAM)']
# [k=4 | Batch 120] Time for generation = 2.80 seconds
# [k=4 | Batch 121] Started generation...
# ['More than 3 solar masses', 'To ensure message anonymity by preventing sender-recipient linkage.', 'Converts stearic acid to oleic acid', 'Energy savings and convenience in lighting control.']
# [k=4 | Batch 121] Time for generation = 3.21 seconds
# [k=4 | Batch 122] Started generation...
# ['Converts serine into pyruvate', 'To confirm a diagnosis of wrist abnormalities.', 'To treat abnormal blood lipid levels.', 'Van der Waals forces and electrical double layer forces']
# [k=4 | Batch 122] Time for generation = 2.56 seconds
# [k=4 | Batch 123] Started generation...
# ['Determine linear independence of functions or solutions to differential equations.', 'Calcium carbonate, calcium sulfate, silica/metal silicates, barium sulfate, and calcium phosph', 'CxH2x (where x is the number of carbon atoms)', 'Inhalation']
# [k=4 | Batch 123] Time for generation = 4.98 seconds
# [k=4 | Batch 124] Started generation...
# ['Funnel-shaped', 'About 15,000 km', 'Warm compresses, eyelid scrubs, gland expression, Lifitegrast, Restasis, IPL treatments, and me', 'Breaks down interstitial collagens types I, II, and III.']
# [k=4 | Batch 124] Time for generation = 4.94 seconds
# Done with k = 4!

# %%
df_true_faiss1 = questions_val[['id', 'answer']].copy()
df_pred_faiss1 = questions_val[['id']].copy()
df_pred_faiss1['answer'] = generated_responses[1]

# %%
df_true_faiss2 = questions_val[['id', 'answer']].copy()
df_pred_faiss2 = questions_val[['id']].copy()
df_pred_faiss2['answer'] = generated_responses[2]

# %%
df_true_faiss3 = questions_val[['id', 'answer']].copy()
df_pred_faiss3 = questions_val[['id']].copy()
df_pred_faiss3['answer'] = generated_responses[3]

# %%
df_true_faiss4 = questions_val[['id', 'answer']].copy()
df_pred_faiss4 = questions_val[['id']].copy()
df_pred_faiss4['answer'] = generated_responses[4]

# %%
bleu_1 = evaluate_bleu(df_true_faiss4, df_pred_faiss4, 1)
bleu_2 = evaluate_bleu(df_true_faiss4, df_pred_faiss4, 2)

print(f"Le score BLEU-1 pour k = {k} est {bleu_1:.3f}.")
print(f"Le score BLEU-2 pour k = {k} est {bleu_2:.3f}.")
# Out:
# Le score BLEU-1 pour k = 4 est 0.440.
# Le score BLEU-2 pour k = 4 est 0.285.

# %% [markdown]
# ### 3.4 Évaluation des réponses (3 points)
#
# Utilisez la métrique BLEU (BLEU-1 et BLEU-2) pour évaluer les réponses générées par rapport aux réponses attendues sur le jeu de validation.

# %%
for k in range(1, 5):
    df_true_faiss = questions_val[['id', 'answer']].copy()
    df_pred_faiss = questions_val[['id']].copy()
    df_pred_faiss['answer'] = generated_responses[k]
    
    bleu_1 = evaluate_bleu(df_true_faiss, df_pred_faiss, 1)
    bleu_2 = evaluate_bleu(df_true_faiss, df_pred_faiss, 2)
    
    print(f"Le score BLEU-1 pour k = {k} est {bleu_1:.3f}.")
    print(f"Le score BLEU-2 pour k = {k} est {bleu_2:.3f}.")

# %% [markdown]
# En vous basant sur les résultats de génération du modèle sur l'ensemble de validation, quel est le nombre optimal de passages à passer au modèle ? Qu'en concluez-vous par rapport au nombre optimal de passages trouvé à la question 3.1.4 ?

# %% [markdown]
# > Réponse

# %% [markdown]
# ### 3.5 Test de soumission Kaggle
# Faites également une soumission Kaggle de votre modèle RAG sur le fichier de test et reportez la valeur obtenue ici.

# %%
submission_df = pd.DataFrame({
    "id": questions_test["id"],
    "answer": generated_responses
})

submission_df.to_csv("tp4_submission.csv", index=False)

# %% [markdown]
# ## 4. Compétition Kaggle (40 points)
#
# Dans cette partie, vous devez implémenter votre propre méthode pour répondre aux questions. Pour rappel, vous ne pouvez pas utiliser de données externes pour entraîner vos modèles, seulement les données fournies, et vous devez utiliser le modèle de génération **'microsoft/Phi-3-mini-128k-instruct'**.
#
# Proposez une architecture plus complexe, ou améliorez les modèles des parties précédentes, afin d’obtenir un score plus élevé que vos autres modèles sur l’ensemble de validation ET dans la compétition Kaggle. Démontrez bien cette amélioration dans votre notebook dans les cellules suivantes. Un autre objectif est d'obtenir le meilleur score de la classe.
#
# Vous devez commencer cette démarche par un état de l'art.
#
# ### 4.1. État de l'art (5 points)
#
# Décrivez en **deux paragraphes**, dans une cellule du notebook, avec les références appropriées, les approches de l’état de l’art pour la tâche que vous tentez d'accomplir. Utilisez une recherche dans Google Scholar.
#
# En vous basant sur vos recherches, quelles sont les meilleures techniques de l’état de l’art ?  Soyez brefs et clairs. Attention, on ne vous demande pas les détails d'un papier particulier mais une synthèse des meilleures approches de l'état de l'art.

# %% [markdown]
# Synthèse:

# %% [markdown]
# Références: Listez vos références de manière appropriée (4-5 parmi les meilleures approches)

# %% [markdown]
# ### 4.2. Description de votre méthode (5 points)
#
# Décrivez en deux paragraphes l'architecture proposée en soulignant notamment les additions ou l'originalité de l'approche et comment l'état de l'art l'a inspirée

# %%
hard_negative_pairs = [
    {
        "question": "What is AI?",
        "positive": "Artificial intelligence is the simulation of human intelligence by machines.",
        "negatives": [
            "AI stands for Adobe Illustrator.",  # Hard negative
            "The sky is blue."  # Easy negative
        ]
    },
    {
        "question": "What is deep learning?",
        "positive": "Deep learning is a subset of machine learning focused on neural networks.",
        "negatives": [
            "Deep learning refers to scuba diving.",  # Hard negative
            "Python is a programming language."  # Easy negative
        ]
    }
]

# %% [markdown]
# ### 4.3. Implémentation (20 points)
#
# Implémentez votre modèle ci-dessous dans une ou plusieurs cellules (veillez à la qualité de votre code) et effectuez votre soumission sur Kaggle en respectant le format de soumission.

# %%
questions_train
# Out:
#       Unnamed: 0.1  Unnamed: 0    id                text_ids  \
# 0             1384           0  2303  [9797 8675 11007 4654]
# 1             2157           0  2310    [736 9830 5892 3158]
# 2             1685           0  2548            [10371 6103]
# 3             1122           0   552       [11829 6677 7137]
# 4             1799           0  1822             [4105 1016]
# ...            ...         ...   ...                     ...
# 1742           134           0  2260  [4076 8293 7629 12061]
# 1743          2243           0  1289            [12861 3692]
# 1744          1928           0   106           [11855 10102]
# 1745           949           0  1324           [11099 13295]
# 1746          2055           0  1798            [11927 8376]
#
#                                                question  \
# 0     What type of insects are vectors for the Haemo...
# 1     What is the basis of the security of the BBS a...
# 2     What is the purpose of the catalase test in ba...
# 3     What type of cells clear small particles in ve...
# 4     What information is needed to decrypt a messag...
# ...                                                 ...
# 1742          What is the function of the NELF complex?
# 1743     What is the main function of SHBG in the body?
# 1744  What is the name of the fungus that causes pec...
# 1745  What technique is an image-based method that c...
# 1746  What is the relative binding affinity of BOMT ...
#
#                                                  answer
# 0         Ceratopogonidae, Culicidae, and Nycteribiidae
# 1     The computational difficulty of factoring larg...
# 2     To identify bacterial species and determine th...
# 3                           Scavenger endothelial cells
# 4                                The user's private key
# ...                                                 ...
# 1742            It acts as a negative elongation factor
# 1743  It binds to androgens and estrogens, inhibitin...
# 1744                              Glomerella cingulata.
# 1745        The method of generalized projections (MGP)
# 1746                  About 2.7% of that of metribolone
#
# [1747 rows x 6 columns]

# %% [markdown]
# ### 4.4. Évaluation (2 points)
#
# #### 4.4.1. Évaluez votre modèle sur le jeu de validation en utilisant la métrique BLEU-2 (1 point)

# %% [markdown]
# #### 4.4.2 Comparez les résultats obtenus avec les modèles précédents sur l'ensemble de validation. Quelles sont vos conclusions? (1 point)

# %% [markdown]
# ### 4.5. Analyse (8 points)
# #### 4.5.1. Avantages/limites/Erreurs types (5 points)
# En quelques phrases précises, discutez des avantages et limites de votre meilleure architecture. Analysez les cas d’erreur.

# %% [markdown]
# #### 4.5.2. Améliorations potentielles (3 points)
#
# Indiquez deux pistes d’amélioration futures potentielles et pourquoi vous pensez qu'elles permettraient d'obtenir de meilleurs résultats en vous basant sur un raisonnement logique ou sur des références à l'état de l'art
